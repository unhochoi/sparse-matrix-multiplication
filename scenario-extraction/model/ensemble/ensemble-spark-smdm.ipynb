# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import ReLU
from tensorflow.keras.optimizers import Adam

# %%
# 1727, 191
train = pd.read_csv('/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/d-optimal/d-optimal-of-spmm/train-test-csv/1727-nonsquare-train-from-1918-nonsquare-spmm-over-3s.csv')
test = pd.read_csv('/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/d-optimal/d-optimal-of-spmm/train-test-csv/191-nonsquare-test-from-1918-nonsquare-spmm-over-3s.csv')

# %%
# feature 1개 추가

# Train + Valid
X_train = train[['lr','lc','rc','ld','rd','lnnz','rnnz','lr*lc','lc*rc','lr*rc','lr*lc*rc','ld*rd','lr*rc*ld*rd','lr*lc*rc*ld*rd','lnnz*rnnz']] 
y_train = train['sp_smdm']

# Test
X_test = test[['lr','lc','rc','ld','rd','lnnz','rnnz','lr*lc','lc*rc','lr*rc','lr*lc*rc','ld*rd','lr*rc*ld*rd','lr*lc*rc*ld*rd','lnnz*rnnz']] 
y_test = test['sp_smdm']

# %%
# 데이터 표준화(Standardization)
from sklearn.preprocessing import StandardScaler

# 변형 객체 생성
std_scaler = StandardScaler()

# 훈련데이터의 모수 분포 저장
std_scaler.fit(X_train)

# 훈련 데이터 스케일링
X_train_scaled = std_scaler.transform(X_train)

# 테스트 데이터의 스케일링
X_test_scaled = std_scaler.transform(X_test)

# %%
from sklearn.metrics import mean_squared_error

def mape_error(y_test, y_pred):
    y_test, y_pred = np.array(y_test), np.array(y_pred)
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

def rmse_error(y_true, y_pred):
    rmse = np.sqrt(np.mean(np.square(y_pred - y_true))) 
    return rmse

# %% [markdown]
# ### Xgbregressor

# %%
import xgboost as xgb

# Train + Valid cross-validation을 거친, 최적의 하이퍼파라미터를 사용
xgbregressor_model = xgb.XGBRegressor(
objective = 'reg:squarederror',
max_depth=int(15),
learning_rate=0.03043527433312202,
n_estimators=int(117),
subsample=0.7657624341353388,
reg_lambda = 0.6647400190467575,    
min_child_weight = 0.9475568411577447,
n_jobs=-1
                             )
# 모델 훈련
xgbregressor_model.fit(X_train, y_train)
# Out:
# XGBRegressor(learning_rate=0.03043527433312202, max_depth=15,
#              min_child_weight=0.9475568411577447, n_estimators=117, n_jobs=-1,
#              objective='reg:squarederror', reg_lambda=0.6647400190467575,
#              subsample=0.7657624341353388)

# %% [markdown]
# ### dnn

# %%
# 모델 생성
def build_model():

    model=Sequential()

    model.add(Dense(256, activation="relu", input_shape=(X_train.shape[1],)))  
    model.add(Dense(128, activation="relu"))
    model.add(Dense(64, activation="relu"))
    model.add(Dense(32, activation="relu"))
    model.add(Dense(1))
    
    optimizer = Adam(lr=0.01)
    
    model.compile(optimizer=optimizer ,
                  loss='mape',
                  metrics=['mape'])
    return model

dnn_model = build_model()

# %%
# 에포크가 끝날 때마다 점(.)을 출력해 훈련 진행 과정을 표시합니다
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end='')

early_stop = keras.callbacks.EarlyStopping(monitor='val_mape', patience=150)

EPOCHS = 100000

dnn_model.fit(X_train_scaled, 
                y_train,
                epochs=EPOCHS, 
                validation_split = 0.1, 
                verbose =0, 
                callbacks=[early_stop, PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# .....................................................................

# %% [markdown]
# ### rfr

# %%
from sklearn.ensemble import RandomForestRegressor

rfr_model = RandomForestRegressor(
criterion='mse',
max_depth=18,
min_samples_leaf=2, 
min_samples_split=4, 
n_estimators=200
)

rfr_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=18, min_samples_leaf=2, min_samples_split=4,
#                       n_estimators=200)

# %% [markdown]
# ### test

# %%
xgbregressor_y_pred = xgbregressor_model.predict(X_test)
dnn_y_pred = dnn_model.predict(X_test_scaled).reshape(-1,)
rfr_y_pred = rfr_model.predict(X_test)

# %%
print(mape_error(y_test,xgbregressor_y_pred))
print(mape_error(y_test,dnn_y_pred))
print(mape_error(y_test,rfr_y_pred))
# Out:
# 13.194099023973507
# 11.117865289845778
# 17.48727069652112

# %%
result_list = {}
mape_list = np.array([])

# 예측값, 실제값을 확인하며 mape 계산 후 mape_list에 삽입 
for idx,value in enumerate(y_test):
    mape_temp = {}
    median_temp = np.array([])
    
    # 각 모델의 예측값
    xgbregressor_predicate = int(xgbregressor_y_pred[idx])
    dnn_predicate = int(dnn_y_pred[idx])
    rfr_predicate = int(rfr_y_pred[idx])
    
    # 각 모델의 예측값을 배열에 삽입
    median_temp = np.append(median_temp, np.array([xgbregressor_predicate,dnn_predicate,rfr_predicate]))
    
    # median 값 사용
    mape = abs((value - np.median(median_temp)) / value) * 100
    
    # mean 값 사용
    # mape = abs((value - np.mean(median_temp)) / value) * 100
    
    mape_temp['xgb_pred'] = xgbregressor_predicate
    mape_temp['dnn_pred'] = dnn_predicate
    mape_temp['rfr_pred'] = rfr_predicate
    mape_temp['best_pred'] = np.median(median_temp)
    mape_temp['real'] = value
    mape_temp['mape'] = mape

    mape_list = np.append(mape_list,np.array([mape]))
    result_list[idx] = mape_temp

result_list_sort = sorted(result_list.values(), key=lambda x:(x['mape']), reverse=True)
result_list_sort
# Out:
# [{'xgb_pred': 14837,
#   'dnn_pred': 15885,
#   'rfr_pred': 16789,
#   'best_pred': 15885.0,
#   'real': 7017,
#   'mape': 126.37879435656262},
#  {'xgb_pred': 12403,
#   'dnn_pred': 7393,
#   'rfr_pred': 15787,
#   'best_pred': 12403.0,
#   'real': 5957,
#   'mape': 108.20882994796037},
#  {'xgb_pred': 20997,
#   'dnn_pred': 12728,
#   'rfr_pred': 22856,
#   'best_pred': 20997.0,
#   'real': 11563,
#   'mape': 81.58782322926577},
#  {'xgb_pred': 5254,
#   'dnn_pred': 5567,
#   'rfr_pred': 7102,
#   'best_pred': 5567.0,
#   'real': 17398,
#   'mape': 68.00206920335671},
#  {'xgb_pred': 4188,
#   'dnn_pred': 5646,
#   'rfr_pred': 4883,
#   'best_pred': 4883.0,
#   'real': 3060,
#   'mape': 59.57516339869281},
#  {'xgb_pred': 58171,
#   'dnn_pred': 77349,
#   'rfr_pred': 62122,
#   'best_pred': 62122.0,
#   'real': 39889,
#   'mape': 55.73717064854973},
#  {'xgb_pred': 5910,
#   'dnn_pred': 4104,
#   'rfr_pred': 7052,
#   'best_pred': 5910.0,
#   'real': 3975,
#   'mape': 48.679245283018865},
#  {'xgb_pred': 24680,
#   'dnn_pred': 24535,
#   'rfr_pred': 27519,
#   'best_pred': 24680.0,
#   'real': 16718,
#   'mape': 47.625314032779045},
#  {'xgb_pred': 185995,
#   'dnn_pred': 113588,
#   'rfr_pred': 218628,
#   'best_pred': 185995.0,
#   'real': 129739,
#   'mape': 43.36090150224682},
#  {'xgb_pred': 364782,
#   'dnn_pred': 290175,
#   'rfr_pred': 410513,
#   'best_pred': 364782.0,
#   'real': 256834,
#   'mape': 42.030260791016765},
#  {'xgb_pred': 5639,
#   'dnn_pred': 7243,
#   'rfr_pred': 6078,
#   'best_pred': 6078.0,
#   'real': 9925,
#   'mape': 38.76070528967254},
#  {'xgb_pred': 14870,
#   'dnn_pred': 6386,
#   'rfr_pred': 17434,
#   'best_pred': 14870.0,
#   'real': 23063,
#   'mape': 35.52443307462168},
#  {'xgb_pred': 9112,
#   'dnn_pred': 12617,
#   'rfr_pred': 9191,
#   'best_pred': 9191.0,
#   'real': 13824,
#   'mape': 33.51417824074074},
#  {'xgb_pred': 333449,
#   'dnn_pred': 243940,
#   'rfr_pred': 335813,
#   'best_pred': 333449.0,
#   'real': 250958,
#   'mape': 32.87044047211087},
#  {'xgb_pred': 6193,
#   'dnn_pred': 6863,
#   'rfr_pred': 6309,
#   'best_pred': 6309.0,
#   'real': 4750,
#   'mape': 32.821052631578944},
#  {'xgb_pred': 101465,
#   'dnn_pred': 104975,
#   'rfr_pred': 113310,
#   'best_pred': 104975.0,
#   'real': 79804,
#   'mape': 31.541025512505637},
#  {'xgb_pred': 15209,
#   'dnn_pred': 13876,
#   'rfr_pred': 15627,
#   'best_pred': 15209.0,
#   'real': 22135,
#   'mape': 31.289812514117916},
#  {'xgb_pred': 16895,
#   'dnn_pred': 7318,
#   'rfr_pred': 14401,
#   'best_pred': 14401.0,
#   'real': 20471,
#   'mape': 29.65170240828489},
#  {'xgb_pred': 21191,
#   'dnn_pred': 18511,
#   'rfr_pred': 23705,
#   'best_pred': 21191.0,
#   'real': 16468,
#   'mape': 28.679863978625214},
#  {'xgb_pred': 40042,
#   'dnn_pred': 35833,
#   'rfr_pred': 40295,
#   'best_pred': 40042.0,
#   'real': 31280,
#   'mape': 28.01150895140665},
#  {'xgb_pred': 21667,
#   'dnn_pred': 9639,
#   'rfr_pred': 20722,
#   'best_pred': 20722.0,
#   'real': 28625,
#   'mape': 27.608733624454146},
#  {'xgb_pred': 82773,
#   'dnn_pred': 101007,
#   'rfr_pred': 83015,
#   'best_pred': 83015.0,
#   'real': 113954,
#   'mape': 27.15042912052232},
#  {'xgb_pred': 22252,
#   'dnn_pred': 16944,
#   'rfr_pred': 24317,
#   'best_pred': 22252.0,
#   'real': 30421,
#   'mape': 26.853160645606657},
#  {'xgb_pred': 40899,
#   'dnn_pred': 34791,
#   'rfr_pred': 43764,
#   'best_pred': 40899.0,
#   'real': 32653,
#   'mape': 25.253422350166904},
#  {'xgb_pred': 20512,
#   'dnn_pred': 18872,
#   'rfr_pred': 20182,
#   'best_pred': 20182.0,
#   'real': 26982,
#   'mape': 25.201986509524872},
#  {'xgb_pred': 18704,
#   'dnn_pred': 14208,
#   'rfr_pred': 18996,
#   'best_pred': 18704.0,
#   'real': 15038,
#   'mape': 24.378241787471737},
#  {'xgb_pred': 8252,
#   'dnn_pred': 7134,
#   'rfr_pred': 9577,
#   'best_pred': 8252.0,
#   'real': 6687,
#   'mape': 23.403618962165396},
#  {'xgb_pred': 7983,
#   'dnn_pred': 6283,
#   'rfr_pred': 8010,
#   'best_pred': 7983.0,
#   'real': 6498,
#   'mape': 22.85318559556787},
#  {'xgb_pred': 16425,
#   'dnn_pred': 17972,
#   'rfr_pred': 17424,
#   'best_pred': 17424.0,
#   'real': 14359,
#   'mape': 21.345497597325718},
#  {'xgb_pred': 273662,
#   'dnn_pred': 261660,
#   'rfr_pred': 314234,
#   'best_pred': 273662.0,
#   'real': 227838,
#   'mape': 20.112536100211553},
#  {'xgb_pred': 11608,
#   'dnn_pred': 12065,
#   'rfr_pred': 11354,
#   'best_pred': 11608.0,
#   'real': 9690,
#   'mape': 19.79360165118679},
#  {'xgb_pred': 21878,
#   'dnn_pred': 23438,
#   'rfr_pred': 28500,
#   'best_pred': 23438.0,
#   'real': 29120,
#   'mape': 19.51236263736264},
#  {'xgb_pred': 15362,
#   'dnn_pred': 21007,
#   'rfr_pred': 15514,
#   'best_pred': 15514.0,
#   'real': 19202,
#   'mape': 19.206332673679825},
#  {'xgb_pred': 58494,
#   'dnn_pred': 46496,
#   'rfr_pred': 56710,
#   'best_pred': 56710.0,
#   'real': 47641,
#   'mape': 19.036124346676182},
#  {'xgb_pred': 201186,
#   'dnn_pred': 270662,
#   'rfr_pred': 174873,
#   'best_pred': 201186.0,
#   'real': 247887,
#   'mape': 18.83963257451984},
#  {'xgb_pred': 105611,
#   'dnn_pred': 92579,
#   'rfr_pred': 119480,
#   'best_pred': 105611.0,
#   'real': 88970,
#   'mape': 18.704057547487917},
#  {'xgb_pred': 14449,
#   'dnn_pred': 11695,
#   'rfr_pred': 15827,
#   'best_pred': 14449.0,
#   'real': 12187,
#   'mape': 18.560761467137112},
#  {'xgb_pred': 12686,
#   'dnn_pred': 18019,
#   'rfr_pred': 13276,
#   'best_pred': 13276.0,
#   'real': 16263,
#   'mape': 18.36684498555002},
#  {'xgb_pred': 16372,
#   'dnn_pred': 14188,
#   'rfr_pred': 16065,
#   'best_pred': 16065.0,
#   'real': 13601,
#   'mape': 18.116314976839938},
#  {'xgb_pred': 24079,
#   'dnn_pred': 41611,
#   'rfr_pred': 33619,
#   'best_pred': 33619.0,
#   'real': 40930,
#   'mape': 17.86220376252138},
#  {'xgb_pred': 46856,
#   'dnn_pred': 40242,
#   'rfr_pred': 47522,
#   'best_pred': 46856.0,
#   'real': 39785,
#   'mape': 17.773030036445896},
#  {'xgb_pred': 31734,
#   'dnn_pred': 35499,
#   'rfr_pred': 33688,
#   'best_pred': 33688.0,
#   'real': 40966,
#   'mape': 17.765952253087928},
#  {'xgb_pred': 13369,
#   'dnn_pred': 9853,
#   'rfr_pred': 12884,
#   'best_pred': 12884.0,
#   'real': 10948,
#   'mape': 17.683595177201315},
#  {'xgb_pred': 3365,
#   'dnn_pred': 3828,
#   'rfr_pred': 4008,
#   'best_pred': 3828.0,
#   'real': 3253,
#   'mape': 17.675991392560714},
#  {'xgb_pred': 68434,
#   'dnn_pred': 54424,
#   'rfr_pred': 67810,
#   'best_pred': 67810.0,
#   'real': 57735,
#   'mape': 17.45042002251667},
#  {'xgb_pred': 63841,
#   'dnn_pred': 54156,
#   'rfr_pred': 65399,
#   'best_pred': 63841.0,
#   'real': 54611,
#   'mape': 16.901356869495157},
#  {'xgb_pred': 26944,
#   'dnn_pred': 38659,
#   'rfr_pred': 24257,
#   'best_pred': 26944.0,
#   'real': 32353,
#   'mape': 16.71869687509659},
#  {'xgb_pred': 32049,
#   'dnn_pred': 38455,
#   'rfr_pred': 32889,
#   'best_pred': 32889.0,
#   'real': 39376,
#   'mape': 16.474502234863877},
#  {'xgb_pred': 578047,
#   'dnn_pred': 649078,
#   'rfr_pred': 559838,
#   'best_pred': 578047.0,
#   'real': 684674,
#   'mape': 15.573396974326467},
#  {'xgb_pred': 384737,
#   'dnn_pred': 398207,
#   'rfr_pred': 351899,
#   'best_pred': 384737.0,
#   'real': 455639,
#   'mape': 15.561003338169034},
#  {'xgb_pred': 32570,
#   'dnn_pred': 29265,
#   'rfr_pred': 35727,
#   'best_pred': 32570.0,
#   'real': 28233,
#   'mape': 15.36145645167003},
#  {'xgb_pred': 105900,
#   'dnn_pred': 108214,
#   'rfr_pred': 107545,
#   'best_pred': 107545.0,
#   'real': 126833,
#   'mape': 15.207398705384245},
#  {'xgb_pred': 38126,
#   'dnn_pred': 40460,
#   'rfr_pred': 37624,
#   'best_pred': 38126.0,
#   'real': 44481,
#   'mape': 14.286998943369078},
#  {'xgb_pred': 28476,
#   'dnn_pred': 30310,
#   'rfr_pred': 29574,
#   'best_pred': 29574.0,
#   'real': 25965,
#   'mape': 13.899480069324092},
#  {'xgb_pred': 31764,
#   'dnn_pred': 37610,
#   'rfr_pred': 31159,
#   'best_pred': 31764.0,
#   'real': 36739,
#   'mape': 13.541468194561638},
#  {'xgb_pred': 38470,
#   'dnn_pred': 41928,
#   'rfr_pred': 39845,
#   'best_pred': 39845.0,
#   'real': 46008,
#   'mape': 13.395496435402537},
#  {'xgb_pred': 1729536,
#   'dnn_pred': 1493732,
#   'rfr_pred': 1646010,
#   'best_pred': 1646010.0,
#   'real': 1453712,
#   'mape': 13.22806718249557},
#  {'xgb_pred': 1667003,
#   'dnn_pred': 1505556,
#   'rfr_pred': 1619313,
#   'best_pred': 1619313.0,
#   'real': 1430273,
#   'mape': 13.217057163212898},
#  {'xgb_pred': 31670,
#   'dnn_pred': 36345,
#   'rfr_pred': 32581,
#   'best_pred': 32581.0,
#   'real': 37394,
#   'mape': 12.871048831363321},
#  {'xgb_pred': 42847,
#   'dnn_pred': 54132,
#   'rfr_pred': 45671,
#   'best_pred': 45671.0,
#   'real': 52251,
#   'mape': 12.59306041989627},
#  {'xgb_pred': 10445,
#   'dnn_pred': 9032,
#   'rfr_pred': 11162,
#   'best_pred': 10445.0,
#   'real': 9282,
#   'mape': 12.529627235509588},
#  {'xgb_pred': 30237,
#   'dnn_pred': 32339,
#   'rfr_pred': 28920,
#   'best_pred': 30237.0,
#   'real': 34251,
#   'mape': 11.719365857931155},
#  {'xgb_pred': 14796,
#   'dnn_pred': 12308,
#   'rfr_pred': 15001,
#   'best_pred': 14796.0,
#   'real': 13248,
#   'mape': 11.684782608695652},
#  {'xgb_pred': 67933,
#   'dnn_pred': 74653,
#   'rfr_pred': 67688,
#   'best_pred': 67933.0,
#   'real': 76871,
#   'mape': 11.627271662915796},
#  {'xgb_pred': 698413,
#   'dnn_pred': 755260,
#   'rfr_pred': 649764,
#   'best_pred': 698413.0,
#   'real': 789097,
#   'mape': 11.49212327508532},
#  {'xgb_pred': 46288,
#   'dnn_pred': 67690,
#   'rfr_pred': 50122,
#   'best_pred': 50122.0,
#   'real': 56513,
#   'mape': 11.308902376444358},
#  {'xgb_pred': 29749,
#   'dnn_pred': 27569,
#   'rfr_pred': 31242,
#   'best_pred': 29749.0,
#   'real': 33516,
#   'mape': 11.239408043919322},
#  {'xgb_pred': 4471,
#   'dnn_pred': 4096,
#   'rfr_pred': 5097,
#   'best_pred': 4471.0,
#   'real': 5025,
#   'mape': 11.024875621890546},
#  {'xgb_pred': 13084,
#   'dnn_pred': 13046,
#   'rfr_pred': 13646,
#   'best_pred': 13084.0,
#   'real': 11785,
#   'mape': 11.022486211285534},
#  {'xgb_pred': 17773,
#   'dnn_pred': 15297,
#   'rfr_pred': 18156,
#   'best_pred': 17773.0,
#   'real': 19953,
#   'mape': 10.925675337042048},
#  {'xgb_pred': 244071,
#   'dnn_pred': 306550,
#   'rfr_pred': 258184,
#   'best_pred': 258184.0,
#   'real': 289155,
#   'mape': 10.710864415279001},
#  {'xgb_pred': 56215,
#   'dnn_pred': 54128,
#   'rfr_pred': 55748,
#   'best_pred': 55748.0,
#   'real': 62435,
#   'mape': 10.710338752302395},
#  {'xgb_pred': 250967,
#   'dnn_pred': 265429,
#   'rfr_pred': 249108,
#   'best_pred': 250967.0,
#   'real': 280837,
#   'mape': 10.636062911938241},
#  {'xgb_pred': 1739937,
#   'dnn_pred': 2032043,
#   'rfr_pred': 1743083,
#   'best_pred': 1743083.0,
#   'real': 1948960,
#   'mape': 10.563428700435104},
#  {'xgb_pred': 19656,
#   'dnn_pred': 19390,
#   'rfr_pred': 20807,
#   'best_pred': 19656.0,
#   'real': 21933,
#   'mape': 10.381616741895773},
#  {'xgb_pred': 280096,
#   'dnn_pred': 295896,
#   'rfr_pred': 275450,
#   'best_pred': 280096.0,
#   'real': 312134,
#   'mape': 10.264181409266532},
#  {'xgb_pred': 105839,
#   'dnn_pred': 87826,
#   'rfr_pred': 115681,
#   'best_pred': 105839.0,
#   'real': 96017,
#   'mape': 10.229438536925754},
#  {'xgb_pred': 35835,
#   'dnn_pred': 40883,
#   'rfr_pred': 38855,
#   'best_pred': 38855.0,
#   'real': 43214,
#   'mape': 10.087008839727867},
#  {'xgb_pred': 35895,
#   'dnn_pred': 37055,
#   'rfr_pred': 37049,
#   'best_pred': 37049.0,
#   'real': 33796,
#   'mape': 9.62539945555687},
#  {'xgb_pred': 34626,
#   'dnn_pred': 34693,
#   'rfr_pred': 35152,
#   'best_pred': 34693.0,
#   'real': 38343,
#   'mape': 9.51933860157004},
#  {'xgb_pred': 37464,
#   'dnn_pred': 47521,
#   'rfr_pred': 41169,
#   'best_pred': 41169.0,
#   'real': 45412,
#   'mape': 9.343345371267505},
#  {'xgb_pred': 4975,
#   'dnn_pred': 4198,
#   'rfr_pred': 6056,
#   'best_pred': 4975.0,
#   'real': 4552,
#   'mape': 9.292618629173989},
#  {'xgb_pred': 465005,
#   'dnn_pred': 436300,
#   'rfr_pred': 482857,
#   'best_pred': 465005.0,
#   'real': 425480,
#   'mape': 9.289508320015042},
#  {'xgb_pred': 65135,
#   'dnn_pred': 52444,
#   'rfr_pred': 66241,
#   'best_pred': 65135.0,
#   'real': 59642,
#   'mape': 9.209952717883372},
#  {'xgb_pred': 16696,
#   'dnn_pred': 16148,
#   'rfr_pred': 19682,
#   'best_pred': 16696.0,
#   'real': 18374,
#   'mape': 9.132469794274519},
#  {'xgb_pred': 9803,
#   'dnn_pred': 8719,
#   'rfr_pred': 11830,
#   'best_pred': 9803.0,
#   'real': 8986,
#   'mape': 9.091920765635434},
#  {'xgb_pred': 35347,
#   'dnn_pred': 39677,
#   'rfr_pred': 35419,
#   'best_pred': 35419.0,
#   'real': 38940,
#   'mape': 9.04211607601438},
#  {'xgb_pred': 42922,
#   'dnn_pred': 51157,
#   'rfr_pred': 44985,
#   'best_pred': 44985.0,
#   'real': 49451,
#   'mape': 9.031162160522538},
#  {'xgb_pred': 9954,
#   'dnn_pred': 11357,
#   'rfr_pred': 10025,
#   'best_pred': 10025.0,
#   'real': 10982,
#   'mape': 8.714259697687124},
#  {'xgb_pred': 51654,
#   'dnn_pred': 45149,
#   'rfr_pred': 54183,
#   'best_pred': 51654.0,
#   'real': 47517,
#   'mape': 8.706357724603826},
#  {'xgb_pred': 25812,
#   'dnn_pred': 26541,
#   'rfr_pred': 29894,
#   'best_pred': 26541.0,
#   'real': 24438,
#   'mape': 8.605450527866438},
#  {'xgb_pred': 17980,
#   'dnn_pred': 16163,
#   'rfr_pred': 24901,
#   'best_pred': 17980.0,
#   'real': 16575,
#   'mape': 8.476621417797888},
#  {'xgb_pred': 13734,
#   'dnn_pred': 12086,
#   'rfr_pred': 14478,
#   'best_pred': 13734.0,
#   'real': 12664,
#   'mape': 8.44914718888187},
#  {'xgb_pred': 73311,
#   'dnn_pred': 82548,
#   'rfr_pred': 78924,
#   'best_pred': 78924.0,
#   'real': 86127,
#   'mape': 8.363231042530217},
#  {'xgb_pred': 79777,
#   'dnn_pred': 74819,
#   'rfr_pred': 81867,
#   'best_pred': 79777.0,
#   'real': 73757,
#   'mape': 8.161937172065024},
#  {'xgb_pred': 16632,
#   'dnn_pred': 15612,
#   'rfr_pred': 18622,
#   'best_pred': 16632.0,
#   'real': 15377,
#   'mape': 8.16153996228133},
#  {'xgb_pred': 124266,
#   'dnn_pred': 127416,
#   'rfr_pred': 145472,
#   'best_pred': 127416.0,
#   'real': 138506,
#   'mape': 8.006873348446998},
#  {'xgb_pred': 6488,
#   'dnn_pred': 7295,
#   'rfr_pred': 9160,
#   'best_pred': 7295.0,
#   'real': 6759,
#   'mape': 7.9301671844947474},
#  {'xgb_pred': 72571,
#   'dnn_pred': 82355,
#   'rfr_pred': 74810,
#   'best_pred': 74810.0,
#   'real': 80791,
#   'mape': 7.403052320184179},
#  {'xgb_pred': 51532,
#   'dnn_pred': 63662,
#   'rfr_pred': 50991,
#   'best_pred': 51532.0,
#   'real': 55633,
#   'mape': 7.371524095410997},
#  {'xgb_pred': 744149,
#   'dnn_pred': 671541,
#   'rfr_pred': 703639,
#   'best_pred': 703639.0,
#   'real': 758285,
#   'mape': 7.206525251059957},
#  {'xgb_pred': 504048,
#   'dnn_pred': 437076,
#   'rfr_pred': 490734,
#   'best_pred': 490734.0,
#   'real': 458892,
#   'mape': 6.9388875813917},
#  {'xgb_pred': 563008,
#   'dnn_pred': 501239,
#   'rfr_pred': 608603,
#   'best_pred': 563008.0,
#   'real': 527020,
#   'mape': 6.82858335547038},
#  {'xgb_pred': 985829,
#   'dnn_pred': 862782,
#   'rfr_pred': 1088593,
#   'best_pred': 985829.0,
#   'real': 923861,
#   'mape': 6.707502535554591},
#  {'xgb_pred': 9060,
#   'dnn_pred': 9563,
#   'rfr_pred': 12487,
#   'best_pred': 9563.0,
#   'real': 8970,
#   'mape': 6.610925306577481},
#  {'xgb_pred': 34043,
#   'dnn_pred': 34277,
#   'rfr_pred': 36151,
#   'best_pred': 34277.0,
#   'real': 36690,
#   'mape': 6.576723902970836},
#  {'xgb_pred': 7787,
#   'dnn_pred': 7775,
#   'rfr_pred': 9923,
#   'best_pred': 7787.0,
#   'real': 8320,
#   'mape': 6.406249999999999},
#  {'xgb_pred': 37291,
#   'dnn_pred': 35128,
#   'rfr_pred': 38984,
#   'best_pred': 37291.0,
#   'real': 35055,
#   'mape': 6.378547996006276},
#  {'xgb_pred': 35285,
#   'dnn_pred': 26873,
#   'rfr_pred': 41281,
#   'best_pred': 35285.0,
#   'real': 33172,
#   'mape': 6.369829977089111},
#  {'xgb_pred': 19820,
#   'dnn_pred': 20050,
#   'rfr_pred': 19217,
#   'best_pred': 19820.0,
#   'real': 18635,
#   'mape': 6.359001878186208},
#  {'xgb_pred': 24812,
#   'dnn_pred': 27379,
#   'rfr_pred': 26511,
#   'best_pred': 26511.0,
#   'real': 28241,
#   'mape': 6.125845402074997},
#  {'xgb_pred': 399121,
#   'dnn_pred': 377823,
#   'rfr_pred': 429851,
#   'best_pred': 399121.0,
#   'real': 376280,
#   'mape': 6.070213670670777},
#  {'xgb_pred': 7014,
#   'dnn_pred': 5673,
#   'rfr_pred': 7977,
#   'best_pred': 7014.0,
#   'real': 6613,
#   'mape': 6.063813700287312},
#  {'xgb_pred': 70903,
#   'dnn_pred': 68190,
#   'rfr_pred': 76388,
#   'best_pred': 70903.0,
#   'real': 75464,
#   'mape': 6.043941482031167},
#  {'xgb_pred': 18679,
#   'dnn_pred': 16079,
#   'rfr_pred': 19616,
#   'best_pred': 18679.0,
#   'real': 17615,
#   'mape': 6.040306556911723},
#  {'xgb_pred': 43013,
#   'dnn_pred': 39357,
#   'rfr_pred': 48874,
#   'best_pred': 43013.0,
#   'real': 40650,
#   'mape': 5.813038130381304},
#  {'xgb_pred': 4714,
#   'dnn_pred': 3459,
#   'rfr_pred': 6001,
#   'best_pred': 4714.0,
#   'real': 4463,
#   'mape': 5.624019717678692},
#  {'xgb_pred': 76659,
#   'dnn_pred': 73079,
#   'rfr_pred': 90694,
#   'best_pred': 76659.0,
#   'real': 81227,
#   'mape': 5.623745798810741},
#  {'xgb_pred': 12957,
#   'dnn_pred': 14341,
#   'rfr_pred': 15889,
#   'best_pred': 14341.0,
#   'real': 13606,
#   'mape': 5.40202851683081},
#  {'xgb_pred': 353487,
#   'dnn_pred': 348205,
#   'rfr_pred': 363413,
#   'best_pred': 353487.0,
#   'real': 373401,
#   'mape': 5.333140511139499},
#  {'xgb_pred': 7869,
#   'dnn_pred': 7022,
#   'rfr_pred': 7727,
#   'best_pred': 7727.0,
#   'real': 7338,
#   'mape': 5.301171981466339},
#  {'xgb_pred': 15603,
#   'dnn_pred': 17591,
#   'rfr_pred': 16176,
#   'best_pred': 16176.0,
#   'real': 17051,
#   'mape': 5.131663832033312},
#  {'xgb_pred': 156948,
#   'dnn_pred': 153937,
#   'rfr_pred': 154891,
#   'best_pred': 154891.0,
#   'real': 163267,
#   'mape': 5.130246773689723},
#  {'xgb_pred': 45507,
#   'dnn_pred': 45440,
#   'rfr_pred': 48292,
#   'best_pred': 45507.0,
#   'real': 43302,
#   'mape': 5.092143549951503},
#  {'xgb_pred': 205981,
#   'dnn_pred': 207770,
#   'rfr_pred': 215287,
#   'best_pred': 207770.0,
#   'real': 198283,
#   'mape': 4.784575581366028},
#  {'xgb_pred': 22585,
#   'dnn_pred': 24603,
#   'rfr_pred': 23496,
#   'best_pred': 23496.0,
#   'real': 22429,
#   'mape': 4.757233938205002},
#  {'xgb_pred': 48600,
#   'dnn_pred': 42384,
#   'rfr_pred': 51146,
#   'best_pred': 48600.0,
#   'real': 46393,
#   'mape': 4.757183195740737},
#  {'xgb_pred': 29709,
#   'dnn_pred': 29184,
#   'rfr_pred': 32332,
#   'best_pred': 29709.0,
#   'real': 28369,
#   'mape': 4.723465754873278},
#  {'xgb_pred': 273184,
#   'dnn_pred': 297182,
#   'rfr_pred': 319566,
#   'best_pred': 297182.0,
#   'real': 283880,
#   'mape': 4.685782725095111},
#  {'xgb_pred': 27412,
#   'dnn_pred': 27805,
#   'rfr_pred': 27954,
#   'best_pred': 27805.0,
#   'real': 26564,
#   'mape': 4.671736184309592},
#  {'xgb_pred': 195462,
#   'dnn_pred': 192439,
#   'rfr_pred': 204451,
#   'best_pred': 195462.0,
#   'real': 204657,
#   'mape': 4.492883214353773},
#  {'xgb_pred': 337663,
#   'dnn_pred': 333103,
#   'rfr_pred': 351333,
#   'best_pred': 337663.0,
#   'real': 353303,
#   'mape': 4.426795130525356},
#  {'xgb_pred': 11684,
#   'dnn_pred': 11513,
#   'rfr_pred': 14075,
#   'best_pred': 11684.0,
#   'real': 12204,
#   'mape': 4.260898066207801},
#  {'xgb_pred': 4924,
#   'dnn_pred': 4946,
#   'rfr_pred': 5597,
#   'best_pred': 4946.0,
#   'real': 4745,
#   'mape': 4.236037934668071},
#  {'xgb_pred': 28965,
#   'dnn_pred': 28591,
#   'rfr_pred': 30313,
#   'best_pred': 28965.0,
#   'real': 27841,
#   'mape': 4.03721130706512},
#  {'xgb_pred': 14851,
#   'dnn_pred': 13559,
#   'rfr_pred': 18409,
#   'best_pred': 14851.0,
#   'real': 15450,
#   'mape': 3.877022653721683},
#  {'xgb_pred': 487384,
#   'dnn_pred': 476790,
#   'rfr_pred': 538464,
#   'best_pred': 487384.0,
#   'real': 505289,
#   'mape': 3.543516680553109},
#  {'xgb_pred': 245017,
#   'dnn_pred': 237939,
#   'rfr_pred': 248613,
#   'best_pred': 245017.0,
#   'real': 236676,
#   'mape': 3.524227213574676},
#  {'xgb_pred': 62267,
#   'dnn_pred': 70989,
#   'rfr_pred': 63445,
#   'best_pred': 63445.0,
#   'real': 65729,
#   'mape': 3.474874104276651},
#  {'xgb_pred': 175987,
#   'dnn_pred': 159039,
#   'rfr_pred': 176472,
#   'best_pred': 175987.0,
#   'real': 170175,
#   'mape': 3.415307771411782},
#  {'xgb_pred': 352050,
#   'dnn_pred': 368124,
#   'rfr_pred': 340306,
#   'best_pred': 352050.0,
#   'real': 364490,
#   'mape': 3.4129880106450106},
#  {'xgb_pred': 25929,
#   'dnn_pred': 29351,
#   'rfr_pred': 28737,
#   'best_pred': 28737.0,
#   'real': 29746,
#   'mape': 3.3920527129698113},
#  {'xgb_pred': 33152,
#   'dnn_pred': 34796,
#   'rfr_pred': 32969,
#   'best_pred': 33152.0,
#   'real': 34302,
#   'mape': 3.3525741939245526},
#  {'xgb_pred': 92448,
#   'dnn_pred': 83748,
#   'rfr_pred': 91267,
#   'best_pred': 91267.0,
#   'real': 94304,
#   'mape': 3.220436036647438},
#  {'xgb_pred': 15690,
#   'dnn_pred': 14641,
#   'rfr_pred': 19735,
#   'best_pred': 15690.0,
#   'real': 15202,
#   'mape': 3.210103933692935},
#  {'xgb_pred': 1258332,
#   'dnn_pred': 1262234,
#   'rfr_pred': 1326182,
#   'best_pred': 1262234.0,
#   'real': 1303947,
#   'mape': 3.1989797131325126},
#  {'xgb_pred': 34685,
#   'dnn_pred': 42285,
#   'rfr_pred': 37488,
#   'best_pred': 37488.0,
#   'real': 38662,
#   'mape': 3.0365733795458074},
#  {'xgb_pred': 30343,
#   'dnn_pred': 31442,
#   'rfr_pred': 31575,
#   'best_pred': 31442.0,
#   'real': 30529,
#   'mape': 2.990599102492712},
#  {'xgb_pred': 25096,
#   'dnn_pred': 24923,
#   'rfr_pred': 26589,
#   'best_pred': 25096.0,
#   'real': 24374,
#   'mape': 2.9621728070895217},
#  {'xgb_pred': 20424,
#   'dnn_pred': 23157,
#   'rfr_pred': 22297,
#   'best_pred': 22297.0,
#   'real': 22964,
#   'mape': 2.9045462462985543},
#  {'xgb_pred': 108329,
#   'dnn_pred': 103420,
#   'rfr_pred': 129693,
#   'best_pred': 108329.0,
#   'real': 105371,
#   'mape': 2.807223999013011},
#  {'xgb_pred': 20117,
#   'dnn_pred': 24091,
#   'rfr_pred': 22204,
#   'best_pred': 22204.0,
#   'real': 21604,
#   'mape': 2.7772634697278282},
#  {'xgb_pred': 35348,
#   'dnn_pred': 32758,
#   'rfr_pred': 38594,
#   'best_pred': 35348.0,
#   'real': 34394,
#   'mape': 2.773739605745188},
#  {'xgb_pred': 5690,
#   'dnn_pred': 6911,
#   'rfr_pred': 6156,
#   'best_pred': 6156.0,
#   'real': 6321,
#   'mape': 2.6103464641670624},
#  {'xgb_pred': 86052,
#   'dnn_pred': 78788,
#   'rfr_pred': 90531,
#   'best_pred': 86052.0,
#   'real': 88332,
#   'mape': 2.5811710365439477},
#  {'xgb_pred': 16607,
#   'dnn_pred': 16690,
#   'rfr_pred': 18613,
#   'best_pred': 16690.0,
#   'real': 16283,
#   'mape': 2.49953939691703},
#  {'xgb_pred': 49214,
#   'dnn_pred': 51501,
#   'rfr_pred': 49091,
#   'best_pred': 49214.0,
#   'real': 50465,
#   'mape': 2.47894580402259},
#  {'xgb_pred': 4258,
#   'dnn_pred': 4230,
#   'rfr_pred': 4608,
#   'best_pred': 4258.0,
#   'real': 4363,
#   'mape': 2.4066009626403853},
#  {'xgb_pred': 17875,
#   'dnn_pred': 16822,
#   'rfr_pred': 17279,
#   'best_pred': 17279.0,
#   'real': 17700,
#   'mape': 2.3785310734463274},
#  {'xgb_pred': 17750,
#   'dnn_pred': 17070,
#   'rfr_pred': 19983,
#   'best_pred': 17750.0,
#   'real': 18176,
#   'mape': 2.34375},
#  {'xgb_pred': 28088,
#   'dnn_pred': 28935,
#   'rfr_pred': 30047,
#   'best_pred': 28935.0,
#   'real': 29621,
#   'mape': 2.3159245130144153},
#  {'xgb_pred': 72790,
#   'dnn_pred': 71594,
#   'rfr_pred': 75589,
#   'best_pred': 72790.0,
#   'real': 71149,
#   'mape': 2.306427356674022},
#  {'xgb_pred': 24663,
#   'dnn_pred': 24018,
#   'rfr_pred': 25582,
#   'best_pred': 24663.0,
#   'real': 24172,
#   'mape': 2.0312758563627336},
#  {'xgb_pred': 66186,
#   'dnn_pred': 58500,
#   'rfr_pred': 70589,
#   'best_pred': 66186.0,
#   'real': 64903,
#   'mape': 1.9767961419348876},
#  {'xgb_pred': 98154,
#   'dnn_pred': 88464,
#   'rfr_pred': 97956,
#   'best_pred': 97956.0,
#   'real': 96098,
#   'mape': 1.933442943661679},
#  {'xgb_pred': 190691,
#   'dnn_pred': 180275,
#   'rfr_pred': 195063,
#   'best_pred': 190691.0,
#   'real': 193726,
#   'mape': 1.5666456748190745},
#  {'xgb_pred': 33186,
#   'dnn_pred': 35877,
#   'rfr_pred': 33111,
#   'best_pred': 33186.0,
#   'real': 32687,
#   'mape': 1.5266007893046165},
#  {'xgb_pred': 9255,
#   'dnn_pred': 14487,
#   'rfr_pred': 10570,
#   'best_pred': 10570.0,
#   'real': 10414,
#   'mape': 1.4979834837718455},
#  {'xgb_pred': 7365,
#   'dnn_pred': 6759,
#   'rfr_pred': 8686,
#   'best_pred': 7365.0,
#   'real': 7471,
#   'mape': 1.4188194351492438},
#  {'xgb_pred': 82588,
#   'dnn_pred': 76150,
#   'rfr_pred': 95478,
#   'best_pred': 82588.0,
#   'real': 83752,
#   'mape': 1.3898175565956634},
#  {'xgb_pred': 267260,
#   'dnn_pred': 243659,
#   'rfr_pred': 285028,
#   'best_pred': 267260.0,
#   'real': 263691,
#   'mape': 1.3534781240163676},
#  {'xgb_pred': 85564,
#   'dnn_pred': 94098,
#   'rfr_pred': 85745,
#   'best_pred': 85745.0,
#   'real': 86842,
#   'mape': 1.2632136523801847},
#  {'xgb_pred': 12694,
#   'dnn_pred': 12023,
#   'rfr_pred': 12896,
#   'best_pred': 12694.0,
#   'real': 12848,
#   'mape': 1.1986301369863013},
#  {'xgb_pred': 33784,
#   'dnn_pred': 39603,
#   'rfr_pred': 37631,
#   'best_pred': 37631.0,
#   'real': 37234,
#   'mape': 1.0662297899769029},
#  {'xgb_pred': 17278,
#   'dnn_pred': 17054,
#   'rfr_pred': 18355,
#   'best_pred': 17278.0,
#   'real': 17102,
#   'mape': 1.029119401239621},
#  {'xgb_pred': 215599,
#   'dnn_pred': 216763,
#   'rfr_pred': 232271,
#   'best_pred': 216763.0,
#   'real': 214583,
#   'mape': 1.0159239082313138},
#  {'xgb_pred': 52539,
#   'dnn_pred': 52127,
#   'rfr_pred': 54961,
#   'best_pred': 52539.0,
#   'real': 53072,
#   'mape': 1.0042960506481762},
#  {'xgb_pred': 82651,
#   'dnn_pred': 70918,
#   'rfr_pred': 87136,
#   'best_pred': 82651.0,
#   'real': 83477,
#   'mape': 0.9894941121506523},
#  {'xgb_pred': 6897,
#   'dnn_pred': 5662,
#   'rfr_pred': 7505,
#   'best_pred': 6897.0,
#   'real': 6835,
#   'mape': 0.9070958302852962},
#  {'xgb_pred': 9877,
#   'dnn_pred': 10176,
#   'rfr_pred': 11711,
#   'best_pred': 10176.0,
#   'real': 10260,
#   'mape': 0.8187134502923977},
#  {'xgb_pred': 20465,
#   'dnn_pred': 18843,
#   'rfr_pred': 18866,
#   'best_pred': 18866.0,
#   'real': 18997,
#   'mape': 0.6895825656682634},
#  {'xgb_pred': 22543,
#   'dnn_pred': 23743,
#   'rfr_pred': 22879,
#   'best_pred': 22879.0,
#   'real': 23037,
#   'mape': 0.6858531926900204},
#  {'xgb_pred': 5875,
#   'dnn_pred': 6285,
#   'rfr_pred': 7369,
#   'best_pred': 6285.0,
#   'real': 6244,
#   'mape': 0.6566303651505445},
#  {'xgb_pred': 18467,
#   'dnn_pred': 18473,
#   'rfr_pred': 20826,
#   'best_pred': 18473.0,
#   'real': 18578,
#   'mape': 0.5651846269781462},
#  {'xgb_pred': 5188,
#   'dnn_pred': 4542,
#   'rfr_pred': 5136,
#   'best_pred': 5136.0,
#   'real': 5164,
#   'mape': 0.5422153369481022},
#  {'xgb_pred': 187194,
#   'dnn_pred': 168263,
#   'rfr_pred': 200514,
#   'best_pred': 187194.0,
#   'real': 186192,
#   'mape': 0.5381541634441867},
#  {'xgb_pred': 15246,
#   'dnn_pred': 17261,
#   'rfr_pred': 15890,
#   'best_pred': 15890.0,
#   'real': 15942,
#   'mape': 0.3261824112407477},
#  {'xgb_pred': 69684,
#   'dnn_pred': 74286,
#   'rfr_pred': 73096,
#   'best_pred': 73096.0,
#   'real': 73296,
#   'mape': 0.2728661864221786},
#  {'xgb_pred': 155616,
#   'dnn_pred': 145773,
#   'rfr_pred': 177893,
#   'best_pred': 155616.0,
#   'real': 156010,
#   'mape': 0.25254791359528234},
#  {'xgb_pred': 30073,
#   'dnn_pred': 34421,
#   'rfr_pred': 32710,
#   'best_pred': 32710.0,
#   'real': 32770,
#   'mape': 0.183094293561184},
#  {'xgb_pred': 238548,
#   'dnn_pred': 240162,
#   'rfr_pred': 241062,
#   'best_pred': 240162.0,
#   'real': 239740,
#   'mape': 0.17602402602819722},
#  {'xgb_pred': 285504,
#   'dnn_pred': 284920,
#   'rfr_pred': 300820,
#   'best_pred': 285504.0,
#   'real': 285741,
#   'mape': 0.08294224490010185}]

# %%
# 최적의 pred을 골라냈을 때 mape 평균
print(np.mean(mape_list))
# Out:
# 12.687710762568686
