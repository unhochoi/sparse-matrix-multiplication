# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import ReLU
from tensorflow.keras.optimizers import Adam

# %%
# 1727, 191
train = pd.read_csv('/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/d-optimal/d-optimal-of-spmm/train-test-csv/1727-nonsquare-train-from-1918-nonsquare-spmm-over-3s.csv')
test = pd.read_csv('/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/d-optimal/d-optimal-of-spmm/train-test-csv/191-nonsquare-test-from-1918-nonsquare-spmm-over-3s.csv')

# %%
# feature 1개 추가

# Train + Valid
X_train = train[['lr','lc','rc','ld','rd','lnnz','rnnz','lr*lc','lc*rc','lr*rc','lr*lc*rc','ld*rd','lr*rc*ld*rd','lr*lc*rc*ld*rd','lnnz*rnnz']] 
y_train = train['sp_smdm']

# Test
X_test = test[['lr','lc','rc','ld','rd','lnnz','rnnz','lr*lc','lc*rc','lr*rc','lr*lc*rc','ld*rd','lr*rc*ld*rd','lr*lc*rc*ld*rd','lnnz*rnnz']] 
y_test = test['sp_smdm']

# %%
# 데이터 표준화(Standardization)
from sklearn.preprocessing import StandardScaler

# 변형 객체 생성
std_scaler = StandardScaler()

# 훈련데이터의 모수 분포 저장
std_scaler.fit(X_train)

# 훈련 데이터 스케일링
X_train_scaled = std_scaler.transform(X_train)

# 테스트 데이터의 스케일링
X_test_scaled = std_scaler.transform(X_test)

# %%
from sklearn.metrics import mean_squared_error

def mape_error(y_test, y_pred):
    y_test, y_pred = np.array(y_test), np.array(y_pred)
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

def rmse_error(y_true, y_pred):
    rmse = np.sqrt(np.mean(np.square(y_pred - y_true))) 
    return rmse

# %% [markdown]
# ### Xgbregressor

# %%
import xgboost as xgb

# Train + Valid cross-validation을 거친, 최적의 하이퍼파라미터를 사용
xgbregressor_model = xgb.XGBRegressor(
objective = 'reg:squarederror',
max_depth=int(15),
learning_rate=0.03043527433312202,
n_estimators=int(117),
subsample=0.7657624341353388,
reg_lambda = 0.6647400190467575,    
min_child_weight = 0.9475568411577447,
n_jobs=-1
                             )
# 모델 훈련
xgbregressor_model.fit(X_train, y_train)
# Out:
# XGBRegressor(learning_rate=0.03043527433312202, max_depth=15,
#              min_child_weight=0.9475568411577447, n_estimators=117, n_jobs=-1,
#              objective='reg:squarederror', reg_lambda=0.6647400190467575,
#              subsample=0.7657624341353388)

# %% [markdown]
# ### dnn

# %%
# 모델 생성
def build_model():

    model=Sequential()

    model.add(Dense(256, activation="relu", input_shape=(X_train.shape[1],)))  
    model.add(Dense(128, activation="relu"))
    model.add(Dense(64, activation="relu"))
    model.add(Dense(32, activation="relu"))
    model.add(Dense(1))
    
    optimizer = Adam(lr=0.01)
    
    model.compile(optimizer=optimizer ,
                  loss='mape',
                  metrics=['mape'])
    return model

dnn_model = build_model()

# %%
# 에포크가 끝날 때마다 점(.)을 출력해 훈련 진행 과정을 표시합니다
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end='')

early_stop = keras.callbacks.EarlyStopping(monitor='val_mape', patience=150)

EPOCHS = 100000

dnn_model.fit(X_train_scaled, 
                y_train,
                epochs=EPOCHS, 
                validation_split = 0.1, 
                verbose =0, 
                callbacks=[early_stop, PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# .....................................................................

# %% [markdown]
# ### rfr

# %%
# from sklearn.ensemble import RandomForestRegressor

# rfr_model = RandomForestRegressor(
# criterion='mse',
# max_depth=18,
# min_samples_leaf=2, 
# min_samples_split=4, 
# n_estimators=200
# )

# rfr_model.fit(X_train, y_train)

# %% [markdown]
# ### linear regressor

# %%
# from sklearn.linear_model import LinearRegression

# linear_model = LinearRegression()

# linear_model.fit(X_train,y_train)

# %% [markdown]
# ### nnls

# %%
a = 0.00000000e+00 
b = 0.00000000e+00 
c = 0.00000000e+00 
d = 2.55569568e+06
e = 0.00000000e+00 
f = 1.14432758e-02 
g = 0.00000000e+00 
h = 0.00000000e+00
i = 2.02972464e-05 
j = 1.52124806e-05 
k = 1.84902894e-09 
l = 0.00000000e+00
m = 1.73792316e-03 
n = 4.21499426e-06 
o = 0.00000000e+00

# %% [markdown]
# ### test

# %%
xgbregressor_y_pred = xgbregressor_model.predict(X_test)
dnn_y_pred = dnn_model.predict(X_test_scaled).reshape(-1,)
#linear_y_pred = linear_model.predict(X_test)
nnls_y_pred = a*X_test['lr']+b*X_test['lc']+c*X_test['rc']+d*X_test['ld']+e*X_test['rd']+f*X_test['lnnz']+g*X_test['rnnz']+h*X_test['lr*lc']+i*X_test['lc*rc']+j*X_test['lr*rc']+k*X_test['lr*lc*rc']+l*X_test['ld*rd']+m*X_test['lr*rc*ld*rd']+n*X_test['lr*lc*rc*ld*rd']+o*X_test['lnnz*rnnz']
#rfr_y_pred = rfr_model.predict(X_test)

# %%
print(mape_error(y_test,xgbregressor_y_pred))
print(mape_error(y_test,dnn_y_pred))
#print(mape_error(y_test,linear_y_pred))
print(mape_error(y_test,nnls_y_pred))
#print(mape_error(y_test,rfr_y_pred))
# Out:
# 13.194099023973507
# 11.843813552070682
# 164.40545796497275

# %%
result_list = {}
mape_list = np.array([])

# 예측값, 실제값을 확인하며 mape 계산 후 mape_list에 삽입 
for idx,value in enumerate(y_test):
    mape_temp = {}
    median_temp = np.array([])
    
    # 각 모델의 예측값
    xgbregressor_predicate = int(xgbregressor_y_pred[idx])
    dnn_predicate = int(dnn_y_pred[idx])
    #linear_predicate = int(linear_y_pred[idx])
    nnls_predicate = int(nnls_y_pred[idx])
    #rfr_predicate = int(rfr_y_pred[idx])
    
    # 각 모델의 예측값을 배열에 삽입
    median_temp = np.append(median_temp, np.array([xgbregressor_predicate,dnn_predicate,nnls_predicate]))
    
    # median 값 사용
    mape = abs((value - np.median(median_temp)) / value) * 100
    
    # mean 값 사용
    # mape = abs((value - np.mean(median_temp)) / value) * 100
    
    mape_temp['xgb_pred'] = xgbregressor_predicate
    mape_temp['dnn_pred'] = dnn_predicate
    #mape_temp['linear_pred'] = linear_predicate
    mape_temp['nnls_pred'] = nnls_predicate
    #mape_temp['rfr_pred'] = rfr_predicate
    mape_temp['--best_pred--'] = np.median(median_temp)
    mape_temp['real'] = value
    mape_temp['mape'] = mape

    mape_list = np.append(mape_list,np.array([mape]))
    result_list[idx] = mape_temp

result_list_sort = sorted(result_list.values(), key=lambda x:(x['mape']), reverse=True)
result_list_sort
# Out:
# [{'xgb_pred': 14837,
#   'dnn_pred': 12722,
#   'nnls_pred': 30237,
#   '--best_pred--': 14837.0,
#   'real': 7017,
#   'mape': 111.44363688185834},
#  {'xgb_pred': 12403,
#   'dnn_pred': 12384,
#   'nnls_pred': 89099,
#   '--best_pred--': 12403.0,
#   'real': 5957,
#   'mape': 108.20882994796037},
#  {'xgb_pred': 58171,
#   'dnn_pred': 78998,
#   'nnls_pred': 107060,
#   '--best_pred--': 78998.0,
#   'real': 39889,
#   'mape': 98.04457369199528},
#  {'xgb_pred': 4188,
#   'dnn_pred': 5960,
#   'nnls_pred': 10242,
#   '--best_pred--': 5960.0,
#   'real': 3060,
#   'mape': 94.77124183006535},
#  {'xgb_pred': 20997,
#   'dnn_pred': 11404,
#   'nnls_pred': 41978,
#   '--best_pred--': 20997.0,
#   'real': 11563,
#   'mape': 81.58782322926577},
#  {'xgb_pred': 5254,
#   'dnn_pred': 6114,
#   'nnls_pred': 22136,
#   '--best_pred--': 6114.0,
#   'real': 17398,
#   'mape': 64.85802965858144},
#  {'xgb_pred': 9255,
#   'dnn_pred': 16084,
#   'nnls_pred': 29561,
#   '--best_pred--': 16084.0,
#   'real': 10414,
#   'mape': 54.44593816016901},
#  {'xgb_pred': 6488,
#   'dnn_pred': 10374,
#   'nnls_pred': 21338,
#   '--best_pred--': 10374.0,
#   'real': 6759,
#   'mape': 53.484243231247234},
#  {'xgb_pred': 6193,
#   'dnn_pred': 7085,
#   'nnls_pred': 15410,
#   '--best_pred--': 7085.0,
#   'real': 4750,
#   'mape': 49.1578947368421},
#  {'xgb_pred': 5910,
#   'dnn_pred': 4799,
#   'nnls_pred': 58964,
#   '--best_pred--': 5910.0,
#   'real': 3975,
#   'mape': 48.679245283018865},
#  {'xgb_pred': 24680,
#   'dnn_pred': 20665,
#   'nnls_pred': 78346,
#   '--best_pred--': 24680.0,
#   'real': 16718,
#   'mape': 47.625314032779045},
#  {'xgb_pred': 185995,
#   'dnn_pred': 115800,
#   'nnls_pred': 247505,
#   '--best_pred--': 185995.0,
#   'real': 129739,
#   'mape': 43.36090150224682},
#  {'xgb_pred': 364782,
#   'dnn_pred': 289491,
#   'nnls_pred': 406785,
#   '--best_pred--': 364782.0,
#   'real': 256834,
#   'mape': 42.030260791016765},
#  {'xgb_pred': 8252,
#   'dnn_pred': 9141,
#   'nnls_pred': 42698,
#   '--best_pred--': 9141.0,
#   'real': 6687,
#   'mape': 36.6980708838044},
#  {'xgb_pred': 14870,
#   'dnn_pred': 9668,
#   'nnls_pred': 52570,
#   '--best_pred--': 14870.0,
#   'real': 23063,
#   'mape': 35.52443307462168},
#  {'xgb_pred': 333449,
#   'dnn_pred': 253516,
#   'nnls_pred': 752377,
#   '--best_pred--': 333449.0,
#   'real': 250958,
#   'mape': 32.87044047211087},
#  {'xgb_pred': 5639,
#   'dnn_pred': 6990,
#   'nnls_pred': 30980,
#   '--best_pred--': 6990.0,
#   'real': 9925,
#   'mape': 29.571788413098236},
#  {'xgb_pred': 21191,
#   'dnn_pred': 21302,
#   'nnls_pred': 76401,
#   '--best_pred--': 21302.0,
#   'real': 16468,
#   'mape': 29.35389846975953},
#  {'xgb_pred': 13084,
#   'dnn_pred': 15091,
#   'nnls_pred': 61186,
#   '--best_pred--': 15091.0,
#   'real': 11785,
#   'mape': 28.052609249045396},
#  {'xgb_pred': 40042,
#   'dnn_pred': 30994,
#   'nnls_pred': 75175,
#   '--best_pred--': 40042.0,
#   'real': 31280,
#   'mape': 28.01150895140665},
#  {'xgb_pred': 101465,
#   'dnn_pred': 102092,
#   'nnls_pred': 115440,
#   '--best_pred--': 102092.0,
#   'real': 79804,
#   'mape': 27.928424640368902},
#  {'xgb_pred': 11608,
#   'dnn_pred': 12295,
#   'nnls_pred': 29969,
#   '--best_pred--': 12295.0,
#   'real': 9690,
#   'mape': 26.883384932920535},
#  {'xgb_pred': 22252,
#   'dnn_pred': 16204,
#   'nnls_pred': 56688,
#   '--best_pred--': 22252.0,
#   'real': 30421,
#   'mape': 26.853160645606657},
#  {'xgb_pred': 34685,
#   'dnn_pred': 48995,
#   'nnls_pred': 271240,
#   '--best_pred--': 48995.0,
#   'real': 38662,
#   'mape': 26.726501474315867},
#  {'xgb_pred': 26944,
#   'dnn_pred': 40716,
#   'nnls_pred': 57081,
#   '--best_pred--': 40716.0,
#   'real': 32353,
#   'mape': 25.84922572868049},
#  {'xgb_pred': 40899,
#   'dnn_pred': 36394,
#   'nnls_pred': 115590,
#   '--best_pred--': 40899.0,
#   'real': 32653,
#   'mape': 25.253422350166904},
#  {'xgb_pred': 18704,
#   'dnn_pred': 16009,
#   'nnls_pred': 272431,
#   '--best_pred--': 18704.0,
#   'real': 15038,
#   'mape': 24.378241787471737},
#  {'xgb_pred': 21667,
#   'dnn_pred': 12285,
#   'nnls_pred': 27782,
#   '--best_pred--': 21667.0,
#   'real': 28625,
#   'mape': 24.307423580786025},
#  {'xgb_pred': 20512,
#   'dnn_pred': 18681,
#   'nnls_pred': 27850,
#   '--best_pred--': 20512.0,
#   'real': 26982,
#   'mape': 23.97894892891557},
#  {'xgb_pred': 16372,
#   'dnn_pred': 16843,
#   'nnls_pred': 72370,
#   '--best_pred--': 16843.0,
#   'real': 13601,
#   'mape': 23.83648261157268},
#  {'xgb_pred': 7983,
#   'dnn_pred': 6223,
#   'nnls_pred': 17079,
#   '--best_pred--': 7983.0,
#   'real': 6498,
#   'mape': 22.85318559556787},
#  {'xgb_pred': 58494,
#   'dnn_pred': 48237,
#   'nnls_pred': 89928,
#   '--best_pred--': 58494.0,
#   'real': 47641,
#   'mape': 22.780798052097985},
#  {'xgb_pred': 4924,
#   'dnn_pred': 5804,
#   'nnls_pred': 21306,
#   '--best_pred--': 5804.0,
#   'real': 4745,
#   'mape': 22.31822971548999},
#  {'xgb_pred': 13369,
#   'dnn_pred': 7832,
#   'nnls_pred': 119314,
#   '--best_pred--': 13369.0,
#   'real': 10948,
#   'mape': 22.11362805991962},
#  {'xgb_pred': 273662,
#   'dnn_pred': 240038,
#   'nnls_pred': 386138,
#   '--best_pred--': 273662.0,
#   'real': 227838,
#   'mape': 20.112536100211553},
#  {'xgb_pred': 9112,
#   'dnn_pred': 11046,
#   'nnls_pred': 39333,
#   '--best_pred--': 11046.0,
#   'real': 13824,
#   'mape': 20.09548611111111},
#  {'xgb_pred': 16425,
#   'dnn_pred': 17219,
#   'nnls_pred': 25784,
#   '--best_pred--': 17219.0,
#   'real': 14359,
#   'mape': 19.917821575318616},
#  {'xgb_pred': 15209,
#   'dnn_pred': 17833,
#   'nnls_pred': 49072,
#   '--best_pred--': 17833.0,
#   'real': 22135,
#   'mape': 19.43528348768918},
#  {'xgb_pred': 201186,
#   'dnn_pred': 258240,
#   'nnls_pred': 177428,
#   '--best_pred--': 201186.0,
#   'real': 247887,
#   'mape': 18.83963257451984},
#  {'xgb_pred': 105611,
#   'dnn_pred': 92502,
#   'nnls_pred': 110253,
#   '--best_pred--': 105611.0,
#   'real': 88970,
#   'mape': 18.704057547487917},
#  {'xgb_pred': 14449,
#   'dnn_pred': 11779,
#   'nnls_pred': 54648,
#   '--best_pred--': 14449.0,
#   'real': 12187,
#   'mape': 18.560761467137112},
#  {'xgb_pred': 24663,
#   'dnn_pred': 28658,
#   'nnls_pred': 61307,
#   '--best_pred--': 28658.0,
#   'real': 24172,
#   'mape': 18.558662915770313},
#  {'xgb_pred': 68434,
#   'dnn_pred': 58249,
#   'nnls_pred': 104457,
#   '--best_pred--': 68434.0,
#   'real': 57735,
#   'mape': 18.531220230362866},
#  {'xgb_pred': 17773,
#   'dnn_pred': 16338,
#   'nnls_pred': 15924,
#   '--best_pred--': 16338.0,
#   'real': 19953,
#   'mape': 18.117576304315143},
#  {'xgb_pred': 46856,
#   'dnn_pred': 35284,
#   'nnls_pred': 74806,
#   '--best_pred--': 46856.0,
#   'real': 39785,
#   'mape': 17.773030036445896},
#  {'xgb_pred': 16895,
#   'dnn_pred': 7947,
#   'nnls_pred': 17373,
#   '--best_pred--': 16895.0,
#   'real': 20471,
#   'mape': 17.468614137071956},
#  {'xgb_pred': 63841,
#   'dnn_pred': 56705,
#   'nnls_pred': 129389,
#   '--best_pred--': 63841.0,
#   'real': 54611,
#   'mape': 16.901356869495157},
#  {'xgb_pred': 578047,
#   'dnn_pred': 646433,
#   'nnls_pred': 285800,
#   '--best_pred--': 578047.0,
#   'real': 684674,
#   'mape': 15.573396974326467},
#  {'xgb_pred': 384737,
#   'dnn_pred': 401295,
#   'nnls_pred': 327474,
#   '--best_pred--': 384737.0,
#   'real': 455639,
#   'mape': 15.561003338169034},
#  {'xgb_pred': 32570,
#   'dnn_pred': 31854,
#   'nnls_pred': 91649,
#   '--best_pred--': 32570.0,
#   'real': 28233,
#   'mape': 15.36145645167003},
#  {'xgb_pred': 46288,
#   'dnn_pred': 64639,
#   'nnls_pred': 97762,
#   '--best_pred--': 64639.0,
#   'real': 56513,
#   'mape': 14.378992444216376},
#  {'xgb_pred': 17278,
#   'dnn_pred': 19560,
#   'nnls_pred': 56130,
#   '--best_pred--': 19560.0,
#   'real': 17102,
#   'mape': 14.372588001403344},
#  {'xgb_pred': 15362,
#   'dnn_pred': 21917,
#   'nnls_pred': 45790,
#   '--best_pred--': 21917.0,
#   'real': 19202,
#   'mape': 14.139152171648787},
#  {'xgb_pred': 45507,
#   'dnn_pred': 49337,
#   'nnls_pred': 90251,
#   '--best_pred--': 49337.0,
#   'real': 43302,
#   'mape': 13.93700060043416},
#  {'xgb_pred': 31734,
#   'dnn_pred': 35327,
#   'nnls_pred': 64453,
#   '--best_pred--': 35327.0,
#   'real': 40966,
#   'mape': 13.765073475565103},
#  {'xgb_pred': 21878,
#   'dnn_pred': 25176,
#   'nnls_pred': 115553,
#   '--best_pred--': 25176.0,
#   'real': 29120,
#   'mape': 13.543956043956044},
#  {'xgb_pred': 9954,
#   'dnn_pred': 12433,
#   'nnls_pred': 72515,
#   '--best_pred--': 12433.0,
#   'real': 10982,
#   'mape': 13.212529593880895},
#  {'xgb_pred': 37291,
#   'dnn_pred': 39569,
#   'nnls_pred': 105056,
#   '--best_pred--': 39569.0,
#   'real': 35055,
#   'mape': 12.876907716445585},
#  {'xgb_pred': 10445,
#   'dnn_pred': 8982,
#   'nnls_pred': 19067,
#   '--best_pred--': 10445.0,
#   'real': 9282,
#   'mape': 12.529627235509588},
#  {'xgb_pred': 14796,
#   'dnn_pred': 12176,
#   'nnls_pred': 32912,
#   '--best_pred--': 14796.0,
#   'real': 13248,
#   'mape': 11.684782608695652},
#  {'xgb_pred': 28476,
#   'dnn_pred': 28986,
#   'nnls_pred': 64769,
#   '--best_pred--': 28986.0,
#   'real': 25965,
#   'mape': 11.634893125361064},
#  {'xgb_pred': 32049,
#   'dnn_pred': 34802,
#   'nnls_pred': 60739,
#   '--best_pred--': 34802.0,
#   'real': 39376,
#   'mape': 11.616212921576595},
#  {'xgb_pred': 24812,
#   'dnn_pred': 24969,
#   'nnls_pred': 52499,
#   '--best_pred--': 24969.0,
#   'real': 28241,
#   'mape': 11.585991997450515},
#  {'xgb_pred': 698413,
#   'dnn_pred': 736073,
#   'nnls_pred': 507960,
#   '--best_pred--': 698413.0,
#   'real': 789097,
#   'mape': 11.49212327508532},
#  {'xgb_pred': 29749,
#   'dnn_pred': 27813,
#   'nnls_pred': 73803,
#   '--best_pred--': 29749.0,
#   'real': 33516,
#   'mape': 11.239408043919322},
#  {'xgb_pred': 1739937,
#   'dnn_pred': 1971439,
#   'nnls_pred': 1198102,
#   '--best_pred--': 1739937.0,
#   'real': 1948960,
#   'mape': 10.724848124127739},
#  {'xgb_pred': 250967,
#   'dnn_pred': 274288,
#   'nnls_pred': 225696,
#   '--best_pred--': 250967.0,
#   'real': 280837,
#   'mape': 10.636062911938241},
#  {'xgb_pred': 5690,
#   'dnn_pred': 6984,
#   'nnls_pred': 50938,
#   '--best_pred--': 6984.0,
#   'real': 6321,
#   'mape': 10.488846701471285},
#  {'xgb_pred': 30073,
#   'dnn_pred': 36187,
#   'nnls_pred': 81059,
#   '--best_pred--': 36187.0,
#   'real': 32770,
#   'mape': 10.42722001830943},
#  {'xgb_pred': 49214,
#   'dnn_pred': 55643,
#   'nnls_pred': 138019,
#   '--best_pred--': 55643.0,
#   'real': 50465,
#   'mape': 10.260576637273358},
#  {'xgb_pred': 105839,
#   'dnn_pred': 96125,
#   'nnls_pred': 164961,
#   '--best_pred--': 105839.0,
#   'real': 96017,
#   'mape': 10.229438536925754},
#  {'xgb_pred': 4714,
#   'dnn_pred': 4911,
#   'nnls_pred': 20718,
#   '--best_pred--': 4911.0,
#   'real': 4463,
#   'mape': 10.038090970199418},
#  {'xgb_pred': 504048,
#   'dnn_pred': 448696,
#   'nnls_pred': 540130,
#   '--best_pred--': 504048.0,
#   'real': 458892,
#   'mape': 9.840223843518736},
#  {'xgb_pred': 20465,
#   'dnn_pred': 20862,
#   'nnls_pred': 39253,
#   '--best_pred--': 20862.0,
#   'real': 18997,
#   'mape': 9.817339579933673},
#  {'xgb_pred': 20117,
#   'dnn_pred': 23707,
#   'nnls_pred': 66355,
#   '--best_pred--': 23707.0,
#   'real': 21604,
#   'mape': 9.734308461396038},
#  {'xgb_pred': 245017,
#   'dnn_pred': 259573,
#   'nnls_pred': 380172,
#   '--best_pred--': 259573.0,
#   'real': 236676,
#   'mape': 9.674407206476364},
#  {'xgb_pred': 399121,
#   'dnn_pred': 412351,
#   'nnls_pred': 457454,
#   '--best_pred--': 412351.0,
#   'real': 376280,
#   'mape': 9.586212395024981},
#  {'xgb_pred': 69684,
#   'dnn_pred': 80269,
#   'nnls_pred': 110886,
#   '--best_pred--': 80269.0,
#   'real': 73296,
#   'mape': 9.513479589609256},
#  {'xgb_pred': 4975,
#   'dnn_pred': 4480,
#   'nnls_pred': 14700,
#   '--best_pred--': 4975.0,
#   'real': 4552,
#   'mape': 9.292618629173989},
#  {'xgb_pred': 65135,
#   'dnn_pred': 57446,
#   'nnls_pred': 98260,
#   '--best_pred--': 65135.0,
#   'real': 59642,
#   'mape': 9.209952717883372},
#  {'xgb_pred': 16696,
#   'dnn_pred': 16085,
#   'nnls_pred': 46367,
#   '--best_pred--': 16696.0,
#   'real': 18374,
#   'mape': 9.132469794274519},
#  {'xgb_pred': 352050,
#   'dnn_pred': 397649,
#   'nnls_pred': 437385,
#   '--best_pred--': 397649.0,
#   'real': 364490,
#   'mape': 9.097368926445169},
#  {'xgb_pred': 9803,
#   'dnn_pred': 8516,
#   'nnls_pred': 24754,
#   '--best_pred--': 9803.0,
#   'real': 8986,
#   'mape': 9.091920765635434},
#  {'xgb_pred': 48600,
#   'dnn_pred': 50476,
#   'nnls_pred': 105176,
#   '--best_pred--': 50476.0,
#   'real': 46393,
#   'mape': 8.800896687000193},
#  {'xgb_pred': 51654,
#   'dnn_pred': 45812,
#   'nnls_pred': 101817,
#   '--best_pred--': 51654.0,
#   'real': 47517,
#   'mape': 8.706357724603826},
#  {'xgb_pred': 17980,
#   'dnn_pred': 15427,
#   'nnls_pred': 66897,
#   '--best_pred--': 17980.0,
#   'real': 16575,
#   'mape': 8.476621417797888},
#  {'xgb_pred': 13734,
#   'dnn_pred': 13369,
#   'nnls_pred': 34908,
#   '--best_pred--': 13734.0,
#   'real': 12664,
#   'mape': 8.44914718888187},
#  {'xgb_pred': 33784,
#   'dnn_pred': 34107,
#   'nnls_pred': 72419,
#   '--best_pred--': 34107.0,
#   'real': 37234,
#   'mape': 8.398238169415052},
#  {'xgb_pred': 79777,
#   'dnn_pred': 67415,
#   'nnls_pred': 114341,
#   '--best_pred--': 79777.0,
#   'real': 73757,
#   'mape': 8.161937172065024},
#  {'xgb_pred': 16632,
#   'dnn_pred': 15166,
#   'nnls_pred': 29698,
#   '--best_pred--': 16632.0,
#   'real': 15377,
#   'mape': 8.16153996228133},
#  {'xgb_pred': 124266,
#   'dnn_pred': 127325,
#   'nnls_pred': 244961,
#   '--best_pred--': 127325.0,
#   'real': 138506,
#   'mape': 8.072574473308016},
#  {'xgb_pred': 51532,
#   'dnn_pred': 59893,
#   'nnls_pred': 115626,
#   '--best_pred--': 59893.0,
#   'real': 55633,
#   'mape': 7.65732568799094},
#  {'xgb_pred': 15603,
#   'dnn_pred': 15765,
#   'nnls_pred': 22243,
#   '--best_pred--': 15765.0,
#   'real': 17051,
#   'mape': 7.542079643422674},
#  {'xgb_pred': 43013,
#   'dnn_pred': 43625,
#   'nnls_pred': 119169,
#   '--best_pred--': 43625.0,
#   'real': 40650,
#   'mape': 7.318573185731856},
#  {'xgb_pred': 280096,
#   'dnn_pred': 289410,
#   'nnls_pred': 584973,
#   '--best_pred--': 289410.0,
#   'real': 312134,
#   'mape': 7.280206577944089},
#  {'xgb_pred': 7869,
#   'dnn_pred': 7140,
#   'nnls_pred': 16354,
#   '--best_pred--': 7869.0,
#   'real': 7338,
#   'mape': 7.236304170073589},
#  {'xgb_pred': 34043,
#   'dnn_pred': 30198,
#   'nnls_pred': 65672,
#   '--best_pred--': 34043.0,
#   'real': 36690,
#   'mape': 7.214499863723085},
#  {'xgb_pred': 3365,
#   'dnn_pred': 3477,
#   'nnls_pred': 15057,
#   '--best_pred--': 3477.0,
#   'real': 3253,
#   'mape': 6.885951429449738},
#  {'xgb_pred': 563008,
#   'dnn_pred': 488810,
#   'nnls_pred': 734902,
#   '--best_pred--': 563008.0,
#   'real': 527020,
#   'mape': 6.82858335547038},
#  {'xgb_pred': 38470,
#   'dnn_pred': 42889,
#   'nnls_pred': 77364,
#   '--best_pred--': 42889.0,
#   'real': 46008,
#   'mape': 6.779255781603199},
#  {'xgb_pred': 82773,
#   'dnn_pred': 106376,
#   'nnls_pred': 113659,
#   '--best_pred--': 106376.0,
#   'real': 113954,
#   'mape': 6.650051775277744},
#  {'xgb_pred': 108329,
#   'dnn_pred': 112276,
#   'nnls_pred': 133387,
#   '--best_pred--': 112276.0,
#   'real': 105371,
#   'mape': 6.553036414193658},
#  {'xgb_pred': 7787,
#   'dnn_pred': 7254,
#   'nnls_pred': 44849,
#   '--best_pred--': 7787.0,
#   'real': 8320,
#   'mape': 6.406249999999999},
#  {'xgb_pred': 35285,
#   'dnn_pred': 29830,
#   'nnls_pred': 116324,
#   '--best_pred--': 35285.0,
#   'real': 33172,
#   'mape': 6.369829977089111},
#  {'xgb_pred': 19820,
#   'dnn_pred': 18393,
#   'nnls_pred': 23261,
#   '--best_pred--': 19820.0,
#   'real': 18635,
#   'mape': 6.359001878186208},
#  {'xgb_pred': 35895,
#   'dnn_pred': 35672,
#   'nnls_pred': 114781,
#   '--best_pred--': 35895.0,
#   'real': 33796,
#   'mape': 6.21079417682566},
#  {'xgb_pred': 7014,
#   'dnn_pred': 5627,
#   'nnls_pred': 20630,
#   '--best_pred--': 7014.0,
#   'real': 6613,
#   'mape': 6.063813700287312},
#  {'xgb_pred': 985829,
#   'dnn_pred': 868005,
#   'nnls_pred': 798599,
#   '--best_pred--': 868005.0,
#   'real': 923861,
#   'mape': 6.045931151980655},
#  {'xgb_pred': 18679,
#   'dnn_pred': 16800,
#   'nnls_pred': 44407,
#   '--best_pred--': 18679.0,
#   'real': 17615,
#   'mape': 6.040306556911723},
#  {'xgb_pred': 31764,
#   'dnn_pred': 38958,
#   'nnls_pred': 155551,
#   '--best_pred--': 38958.0,
#   'real': 36739,
#   'mape': 6.0399031002476935},
#  {'xgb_pred': 156948,
#   'dnn_pred': 172977,
#   'nnls_pred': 193466,
#   '--best_pred--': 172977.0,
#   'real': 163267,
#   'mape': 5.947313296624547},
#  {'xgb_pred': 17750,
#   'dnn_pred': 19231,
#   'nnls_pred': 56393,
#   '--best_pred--': 19231.0,
#   'real': 18176,
#   'mape': 5.804357394366197},
#  {'xgb_pred': 4258,
#   'dnn_pred': 4615,
#   'nnls_pred': 19283,
#   '--best_pred--': 4615.0,
#   'real': 4363,
#   'mape': 5.775842310336924},
#  {'xgb_pred': 25812,
#   'dnn_pred': 23178,
#   'nnls_pred': 54112,
#   '--best_pred--': 25812.0,
#   'real': 24438,
#   'mape': 5.622391357721581},
#  {'xgb_pred': 30237,
#   'dnn_pred': 36108,
#   'nnls_pred': 58246,
#   '--best_pred--': 36108.0,
#   'real': 34251,
#   'mape': 5.421739511255145},
#  {'xgb_pred': 33186,
#   'dnn_pred': 34440,
#   'nnls_pred': 71832,
#   '--best_pred--': 34440.0,
#   'real': 32687,
#   'mape': 5.362988343989965},
#  {'xgb_pred': 85564,
#   'dnn_pred': 91402,
#   'nnls_pred': 134501,
#   '--best_pred--': 91402.0,
#   'real': 86842,
#   'mape': 5.250915455655098},
#  {'xgb_pred': 62267,
#   'dnn_pred': 69165,
#   'nnls_pred': 115468,
#   '--best_pred--': 69165.0,
#   'real': 65729,
#   'mape': 5.227525141109708},
#  {'xgb_pred': 72790,
#   'dnn_pred': 74868,
#   'nnls_pred': 245869,
#   '--best_pred--': 74868.0,
#   'real': 71149,
#   'mape': 5.22705870778226},
#  {'xgb_pred': 7365,
#   'dnn_pred': 7859,
#   'nnls_pred': 14846,
#   '--best_pred--': 7859.0,
#   'real': 7471,
#   'mape': 5.1934145362066655},
#  {'xgb_pred': 273184,
#   'dnn_pred': 298308,
#   'nnls_pred': 330216,
#   '--best_pred--': 298308.0,
#   'real': 283880,
#   'mape': 5.082429195434691},
#  {'xgb_pred': 25096,
#   'dnn_pred': 25592,
#   'nnls_pred': 50958,
#   '--best_pred--': 25592.0,
#   'real': 24374,
#   'mape': 4.997128087306145},
#  {'xgb_pred': 4471,
#   'dnn_pred': 4775,
#   'nnls_pred': 21242,
#   '--best_pred--': 4775.0,
#   'real': 5025,
#   'mape': 4.975124378109453},
#  {'xgb_pred': 1729536,
#   'dnn_pred': 1522756,
#   'nnls_pred': 800222,
#   '--best_pred--': 1522756.0,
#   'real': 1453712,
#   'mape': 4.7494964614724235},
#  {'xgb_pred': 155616,
#   'dnn_pred': 163418,
#   'nnls_pred': 370033,
#   '--best_pred--': 163418.0,
#   'real': 156010,
#   'mape': 4.748413563233126},
#  {'xgb_pred': 29709,
#   'dnn_pred': 26346,
#   'nnls_pred': 57845,
#   '--best_pred--': 29709.0,
#   'real': 28369,
#   'mape': 4.723465754873278},
#  {'xgb_pred': 42922,
#   'dnn_pred': 51763,
#   'nnls_pred': 94648,
#   '--best_pred--': 51763.0,
#   'real': 49451,
#   'mape': 4.675335180279468},
#  {'xgb_pred': 73311,
#   'dnn_pred': 90090,
#   'nnls_pred': 193499,
#   '--best_pred--': 90090.0,
#   'real': 86127,
#   'mape': 4.601344526106796},
#  {'xgb_pred': 12957,
#   'dnn_pred': 12993,
#   'nnls_pred': 41000,
#   '--best_pred--': 12993.0,
#   'real': 13606,
#   'mape': 4.505365280023519},
#  {'xgb_pred': 190691,
#   'dnn_pred': 202408,
#   'nnls_pred': 355454,
#   '--best_pred--': 202408.0,
#   'real': 193726,
#   'mape': 4.4815873966323565},
#  {'xgb_pred': 195462,
#   'dnn_pred': 195595,
#   'nnls_pred': 198113,
#   '--best_pred--': 195595.0,
#   'real': 204657,
#   'mape': 4.427896431590417},
#  {'xgb_pred': 337663,
#   'dnn_pred': 341521,
#   'nnls_pred': 265559,
#   '--best_pred--': 337663.0,
#   'real': 353303,
#   'mape': 4.426795130525356},
#  {'xgb_pred': 56215,
#   'dnn_pred': 59676,
#   'nnls_pred': 143139,
#   '--best_pred--': 59676.0,
#   'real': 62435,
#   'mape': 4.418995755585809},
#  {'xgb_pred': 15246,
#   'dnn_pred': 14953,
#   'nnls_pred': 29647,
#   '--best_pred--': 15246.0,
#   'real': 15942,
#   'mape': 4.365826119683854},
#  {'xgb_pred': 215599,
#   'dnn_pred': 223815,
#   'nnls_pred': 256971,
#   '--best_pred--': 223815.0,
#   'real': 214583,
#   'mape': 4.302297945317197},
#  {'xgb_pred': 353487,
#   'dnn_pred': 388916,
#   'nnls_pred': 512381,
#   '--best_pred--': 388916.0,
#   'real': 373401,
#   'mape': 4.15505046853115},
#  {'xgb_pred': 25929,
#   'dnn_pred': 28534,
#   'nnls_pred': 62245,
#   '--best_pred--': 28534.0,
#   'real': 29746,
#   'mape': 4.074497411416661},
#  {'xgb_pred': 244071,
#   'dnn_pred': 300873,
#   'nnls_pred': 388689,
#   '--best_pred--': 300873.0,
#   'real': 289155,
#   'mape': 4.0524977953000985},
#  {'xgb_pred': 28965,
#   'dnn_pred': 24860,
#   'nnls_pred': 44449,
#   '--best_pred--': 28965.0,
#   'real': 27841,
#   'mape': 4.03721130706512},
#  {'xgb_pred': 67933,
#   'dnn_pred': 79963,
#   'nnls_pred': 107939,
#   '--best_pred--': 79963.0,
#   'real': 76871,
#   'mape': 4.02232311274733},
#  {'xgb_pred': 38126,
#   'dnn_pred': 42718,
#   'nnls_pred': 100181,
#   '--best_pred--': 42718.0,
#   'real': 44481,
#   'mape': 3.9634900294507767},
#  {'xgb_pred': 205981,
#   'dnn_pred': 206445,
#   'nnls_pred': 174835,
#   '--best_pred--': 205981.0,
#   'real': 198283,
#   'mape': 3.882329801344543},
#  {'xgb_pred': 42847,
#   'dnn_pred': 54237,
#   'nnls_pred': 77286,
#   '--best_pred--': 54237.0,
#   'real': 52251,
#   'mape': 3.8008841936039506},
#  {'xgb_pred': 98154,
#   'dnn_pred': 99745,
#   'nnls_pred': 183854,
#   '--best_pred--': 99745.0,
#   'real': 96098,
#   'mape': 3.795084184894587},
#  {'xgb_pred': 9877,
#   'dnn_pred': 9546,
#   'nnls_pred': 39024,
#   '--best_pred--': 9877.0,
#   'real': 10260,
#   'mape': 3.7329434697855746},
#  {'xgb_pred': 5875,
#   'dnn_pred': 6477,
#   'nnls_pred': 36707,
#   '--best_pred--': 6477.0,
#   'real': 6244,
#   'mape': 3.731582319026265},
#  {'xgb_pred': 72571,
#   'dnn_pred': 83772,
#   'nnls_pred': 84865,
#   '--best_pred--': 83772.0,
#   'real': 80791,
#   'mape': 3.689767424589373},
#  {'xgb_pred': 487384,
#   'dnn_pred': 500477,
#   'nnls_pred': 437760,
#   '--best_pred--': 487384.0,
#   'real': 505289,
#   'mape': 3.543516680553109},
#  {'xgb_pred': 1258332,
#   'dnn_pred': 1293375,
#   'nnls_pred': 874080,
#   '--best_pred--': 1258332.0,
#   'real': 1303947,
#   'mape': 3.4982250045438965},
#  {'xgb_pred': 19656,
#   'dnn_pred': 21176,
#   'nnls_pred': 54140,
#   '--best_pred--': 21176.0,
#   'real': 21933,
#   'mape': 3.4514202343500657},
#  {'xgb_pred': 175987,
#   'dnn_pred': 172139,
#   'nnls_pred': 265023,
#   '--best_pred--': 175987.0,
#   'real': 170175,
#   'mape': 3.415307771411782},
#  {'xgb_pred': 15690,
#   'dnn_pred': 14801,
#   'nnls_pred': 40237,
#   '--best_pred--': 15690.0,
#   'real': 15202,
#   'mape': 3.210103933692935},
#  {'xgb_pred': 27412,
#   'dnn_pred': 25798,
#   'nnls_pred': 61100,
#   '--best_pred--': 27412.0,
#   'real': 26564,
#   'mape': 3.1922903177232342},
#  {'xgb_pred': 33152,
#   'dnn_pred': 33213,
#   'nnls_pred': 55635,
#   '--best_pred--': 33213.0,
#   'real': 34302,
#   'mape': 3.174741997551163},
#  {'xgb_pred': 34626,
#   'dnn_pred': 37147,
#   'nnls_pred': 77401,
#   '--best_pred--': 37147.0,
#   'real': 38343,
#   'mape': 3.1192134157473332},
#  {'xgb_pred': 105900,
#   'dnn_pred': 122914,
#   'nnls_pred': 171687,
#   '--best_pred--': 122914.0,
#   'real': 126833,
#   'mape': 3.089889855163877},
#  {'xgb_pred': 76659,
#   'dnn_pred': 83601,
#   'nnls_pred': 209778,
#   '--best_pred--': 83601.0,
#   'real': 81227,
#   'mape': 2.922673495266352},
#  {'xgb_pred': 70903,
#   'dnn_pred': 73336,
#   'nnls_pred': 141230,
#   '--best_pred--': 73336.0,
#   'real': 75464,
#   'mape': 2.819887628538111},
#  {'xgb_pred': 35348,
#   'dnn_pred': 32003,
#   'nnls_pred': 90636,
#   '--best_pred--': 35348.0,
#   'real': 34394,
#   'mape': 2.773739605745188},
#  {'xgb_pred': 37464,
#   'dnn_pred': 44219,
#   'nnls_pred': 87699,
#   '--best_pred--': 44219.0,
#   'real': 45412,
#   'mape': 2.627058927155818},
#  {'xgb_pred': 86052,
#   'dnn_pred': 90620,
#   'nnls_pred': 143241,
#   '--best_pred--': 90620.0,
#   'real': 88332,
#   'mape': 2.5902277770230495},
#  {'xgb_pred': 238548,
#   'dnn_pred': 244961,
#   'nnls_pred': 276698,
#   '--best_pred--': 244961.0,
#   'real': 239740,
#   'mape': 2.1777759239175776},
#  {'xgb_pred': 1667003,
#   'dnn_pred': 1460470,
#   'nnls_pred': 902100,
#   '--best_pred--': 1460470.0,
#   'real': 1430273,
#   'mape': 2.111275260037769},
#  {'xgb_pred': 16607,
#   'dnn_pred': 16254,
#   'nnls_pred': 49001,
#   '--best_pred--': 16607.0,
#   'real': 16283,
#   'mape': 1.9898053184302649},
#  {'xgb_pred': 66186,
#   'dnn_pred': 65813,
#   'nnls_pred': 127393,
#   '--best_pred--': 66186.0,
#   'real': 64903,
#   'mape': 1.9767961419348876},
#  {'xgb_pred': 744149,
#   'dnn_pred': 699911,
#   'nnls_pred': 965256,
#   '--best_pred--': 744149.0,
#   'real': 758285,
#   'mape': 1.8642067296596925},
#  {'xgb_pred': 465005,
#   'dnn_pred': 433360,
#   'nnls_pred': 357835,
#   '--best_pred--': 433360.0,
#   'real': 425480,
#   'mape': 1.8520259471655542},
#  {'xgb_pred': 35835,
#   'dnn_pred': 42420,
#   'nnls_pred': 126096,
#   '--best_pred--': 42420.0,
#   'real': 43214,
#   'mape': 1.837367519785255},
#  {'xgb_pred': 31670,
#   'dnn_pred': 36708,
#   'nnls_pred': 95029,
#   '--best_pred--': 36708.0,
#   'real': 37394,
#   'mape': 1.8345189067764882},
#  {'xgb_pred': 20424,
#   'dnn_pred': 22565,
#   'nnls_pred': 48359,
#   '--best_pred--': 22565.0,
#   'real': 22964,
#   'mape': 1.7375021773210244},
#  {'xgb_pred': 92448,
#   'dnn_pred': 95823,
#   'nnls_pred': 195806,
#   '--best_pred--': 95823.0,
#   'real': 94304,
#   'mape': 1.610748218527316},
#  {'xgb_pred': 11684,
#   'dnn_pred': 12390,
#   'nnls_pred': 38356,
#   '--best_pred--': 12390.0,
#   'real': 12204,
#   'mape': 1.5240904621435596},
#  {'xgb_pred': 82588,
#   'dnn_pred': 66229,
#   'nnls_pred': 181058,
#   '--best_pred--': 82588.0,
#   'real': 83752,
#   'mape': 1.3898175565956634},
#  {'xgb_pred': 267260,
#   'dnn_pred': 260145,
#   'nnls_pred': 461077,
#   '--best_pred--': 267260.0,
#   'real': 263691,
#   'mape': 1.3534781240163676},
#  {'xgb_pred': 12694,
#   'dnn_pred': 12378,
#   'nnls_pred': 29505,
#   '--best_pred--': 12694.0,
#   'real': 12848,
#   'mape': 1.1986301369863013},
#  {'xgb_pred': 28088,
#   'dnn_pred': 29973,
#   'nnls_pred': 111737,
#   '--best_pred--': 29973.0,
#   'real': 29621,
#   'mape': 1.1883461058033153},
#  {'xgb_pred': 52539,
#   'dnn_pred': 39474,
#   'nnls_pred': 102177,
#   '--best_pred--': 52539.0,
#   'real': 53072,
#   'mape': 1.0042960506481762},
#  {'xgb_pred': 9060,
#   'dnn_pred': 8590,
#   'nnls_pred': 43564,
#   '--best_pred--': 9060.0,
#   'real': 8970,
#   'mape': 1.0033444816053512},
#  {'xgb_pred': 82651,
#   'dnn_pred': 72675,
#   'nnls_pred': 148297,
#   '--best_pred--': 82651.0,
#   'real': 83477,
#   'mape': 0.9894941121506523},
#  {'xgb_pred': 17875,
#   'dnn_pred': 16106,
#   'nnls_pred': 37721,
#   '--best_pred--': 17875.0,
#   'real': 17700,
#   'mape': 0.9887005649717515},
#  {'xgb_pred': 6897,
#   'dnn_pred': 6807,
#   'nnls_pred': 21507,
#   '--best_pred--': 6897.0,
#   'real': 6835,
#   'mape': 0.9070958302852962},
#  {'xgb_pred': 12686,
#   'dnn_pred': 16397,
#   'nnls_pred': 27003,
#   '--best_pred--': 16397.0,
#   'real': 16263,
#   'mape': 0.8239562196396729},
#  {'xgb_pred': 285504,
#   'dnn_pred': 283404,
#   'nnls_pred': 277611,
#   '--best_pred--': 283404.0,
#   'real': 285741,
#   'mape': 0.8178735288250548},
#  {'xgb_pred': 187194,
#   'dnn_pred': 187633,
#   'nnls_pred': 218164,
#   '--best_pred--': 187633.0,
#   'real': 186192,
#   'mape': 0.7739322849531666},
#  {'xgb_pred': 22585,
#   'dnn_pred': 21530,
#   'nnls_pred': 42771,
#   '--best_pred--': 22585.0,
#   'real': 22429,
#   'mape': 0.6955281109278167},
#  {'xgb_pred': 30343,
#   'dnn_pred': 29262,
#   'nnls_pred': 51917,
#   '--best_pred--': 30343.0,
#   'real': 30529,
#   'mape': 0.6092567722493367},
#  {'xgb_pred': 18467,
#   'dnn_pred': 17403,
#   'nnls_pred': 34303,
#   '--best_pred--': 18467.0,
#   'real': 18578,
#   'mape': 0.5974808913768974},
#  {'xgb_pred': 14851,
#   'dnn_pred': 15522,
#   'nnls_pred': 33643,
#   '--best_pred--': 15522.0,
#   'real': 15450,
#   'mape': 0.46601941747572817},
#  {'xgb_pred': 5188,
#   'dnn_pred': 4776,
#   'nnls_pred': 18377,
#   '--best_pred--': 5188.0,
#   'real': 5164,
#   'mape': 0.46475600309837334},
#  {'xgb_pred': 22543,
#   'dnn_pred': 23095,
#   'nnls_pred': 60364,
#   '--best_pred--': 23095.0,
#   'real': 23037,
#   'mape': 0.2517688935191214},
#  {'xgb_pred': 35347,
#   'dnn_pred': 38850,
#   'nnls_pred': 62955,
#   '--best_pred--': 38850.0,
#   'real': 38940,
#   'mape': 0.23112480739599386},
#  {'xgb_pred': 24079,
#   'dnn_pred': 41020,
#   'nnls_pred': 71239,
#   '--best_pred--': 41020.0,
#   'real': 40930,
#   'mape': 0.21988761299780113}]

# %%
# 최적의 pred을 골라냈을 때 mape 평균
print(np.mean(mape_list))
# Out:
# 13.375204054880564
