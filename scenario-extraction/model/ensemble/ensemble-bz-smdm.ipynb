# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import ReLU
from tensorflow.keras.optimizers import Adam

# %%
# 1727, 191
train = pd.read_csv('/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/d-optimal/d-optimal-of-spmm/train-test-csv/1727-nonsquare-train-from-1918-nonsquare-spmm-over-3s.csv')
test = pd.read_csv('/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/d-optimal/d-optimal-of-spmm/train-test-csv/191-nonsquare-test-from-1918-nonsquare-spmm-over-3s.csv')

# %%
# feature 1개 추가

# Train + Valid
X_train = train[['lr','lc','rc','ld','rd','lnnz','rnnz','lr*lc','lc*rc','lr*rc','lr*lc*rc','ld*rd','lr*rc*ld*rd','lr*lc*rc*ld*rd','lnnz*rnnz']] 
y_train = train['bz_smdm']

# Test
X_test = test[['lr','lc','rc','ld','rd','lnnz','rnnz','lr*lc','lc*rc','lr*rc','lr*lc*rc','ld*rd','lr*rc*ld*rd','lr*lc*rc*ld*rd','lnnz*rnnz']] 
y_test = test['bz_smdm']

# %%
#  feature 4개 추가 (xgbregressor 용 feature)

# Train + Valid
X_train_v2 = train[['lr','lc','rc','ld','rd','lnnz','rnnz','lr*lc','lc*rc','lr*rc','lr*lc*rc','ld*rd','lr*rc*ld*rd','lr*lc*rc*ld*rd','lnnz*rnnz','lnnz+rnnz','lnnz+lc*rc','lr*lc+lc*rc']] 

# Test
X_test_v2 = test[['lr','lc','rc','ld','rd','lnnz','rnnz','lr*lc','lc*rc','lr*rc','lr*lc*rc','ld*rd','lr*rc*ld*rd','lr*lc*rc*ld*rd','lnnz*rnnz','lnnz+rnnz','lnnz+lc*rc','lr*lc+lc*rc']]

# %%
# 데이터 표준화(Standardization)
from sklearn.preprocessing import StandardScaler

# 변형 객체 생성
std_scaler = StandardScaler()

# 훈련데이터의 모수 분포 저장
std_scaler.fit(X_train)

# 훈련 데이터 스케일링
X_train_scaled = std_scaler.transform(X_train)

# 테스트 데이터의 스케일링
X_test_scaled = std_scaler.transform(X_test)

# %%
from sklearn.metrics import mean_squared_error

def mape_error(y_test, y_pred):
    y_test, y_pred = np.array(y_test), np.array(y_pred)
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

def rmse_error(y_true, y_pred):
    rmse = np.sqrt(np.mean(np.square(y_pred - y_true))) 
    return rmse

# %% [markdown]
# ### Xgbregressor

# %%
import xgboost as xgb

# Train + Valid cross-validation을 거친, 최적의 하이퍼파라미터를 사용
xgbregressor_model = xgb.XGBRegressor(
objective = 'reg:squarederror',
max_depth=int(14),
learning_rate=0.02398298537228648,
n_estimators=int(149),
subsample=0.5732030368686496,
reg_lambda = 0.36548495335549436,    
n_jobs=-1
                             )
# 모델 훈련
xgbregressor_model.fit(X_train_v2, y_train)
# Out:
# XGBRegressor(learning_rate=0.02398298537228648, max_depth=14, n_estimators=149,
#              n_jobs=-1, objective='reg:squarederror',
#              reg_lambda=0.36548495335549436, subsample=0.5732030368686496)

# %% [markdown]
# ### dnn

# %%
# 모델 생성
def build_model():

    model=Sequential()

    model.add(Dense(256, activation="relu", input_shape=(X_train.shape[1],)))  
    model.add(Dense(128, activation="relu"))
    model.add(Dense(64, activation="relu"))
    model.add(Dense(32, activation="relu"))
    model.add(Dense(1))
    
    optimizer = Adam(lr=0.01)
    
    model.compile(optimizer=optimizer ,
                  loss='mape',
                  metrics=['mape'])
    return model

dnn_model = build_model()

# %%
# 에포크가 끝날 때마다 점(.)을 출력해 훈련 진행 과정을 표시합니다
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end='')

early_stop = keras.callbacks.EarlyStopping(monitor='val_mape', patience=150)

EPOCHS = 100000

dnn_model.fit(X_train_scaled, 
                y_train,
                epochs=EPOCHS, 
                validation_split = 0.1, 
                verbose =0, 
                callbacks=[early_stop, PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ........................................................................................

# %% [markdown]
# ### rfr

# %%
# from sklearn.ensemble import RandomForestRegressor

# rfr_model = RandomForestRegressor(
# criterion='mse',
# max_depth=24,
# min_samples_leaf=2, 
# min_samples_split=4, 
# n_estimators=800
# )

# rfr_model.fit(X_train, y_train)

# %% [markdown]
# ### linear regressor

# %%
# from sklearn.linear_model import LinearRegression

# linear_model = LinearRegression()

# linear_model.fit(X_train,y_train)

# %% [markdown]
# ### nnls

# %%
a = 0.00000000e+00 
b = 0.00000000e+00 
c = 0.00000000e+00 
d = 1.43805650e+07
e = 0.00000000e+00 
f = 2.83696475e-02 
g = 0.00000000e+00 
h = 0.00000000e+00
i = 2.59782718e-04 
j = 1.57085917e-06 
k = 3.07969310e-09 
l = 0.00000000e+00
m = 0.00000000e+00 
n = 1.09879008e-05 
o = 0.00000000e+00

# %% [markdown]
# ### test

# %%
xgbregressor_y_pred = xgbregressor_model.predict(X_test_v2)
dnn_y_pred = dnn_model.predict(X_test_scaled).reshape(-1,)
#linear_y_pred = linear_model.predict(X_test)
nnls_y_pred = a*X_test['lr']+b*X_test['lc']+c*X_test['rc']+d*X_test['ld']+e*X_test['rd']+f*X_test['lnnz']+g*X_test['rnnz']+h*X_test['lr*lc']+i*X_test['lc*rc']+j*X_test['lr*rc']+k*X_test['lr*lc*rc']+l*X_test['ld*rd']+m*X_test['lr*rc*ld*rd']+n*X_test['lr*lc*rc*ld*rd']+o*X_test['lnnz*rnnz']
#rfr_y_pred = rfr_model.predict(X_test)

# %%
print(mape_error(y_test,xgbregressor_y_pred))
print(mape_error(y_test,dnn_y_pred))
#print(mape_error(y_test,linear_y_pred))
print(mape_error(y_test,nnls_y_pred))
#print(mape_error(y_test,rfr_y_pred))
# Out:
# 12.307202381784455
# 12.549889011008691
# 269.62309853047265

# %%
result_list = {}
mape_list = np.array([])

# 예측값, 실제값을 확인하며 mape 계산 후 mape_list에 삽입 
for idx,value in enumerate(y_test):
    mape_temp = {}
    median_temp = np.array([])
    
    # 각 모델의 예측값
    xgbregressor_predicate = int(xgbregressor_y_pred[idx])
    dnn_predicate = int(dnn_y_pred[idx])
    #linear_predicate = int(linear_y_pred[idx])
    nnls_predicate = int(nnls_y_pred[idx])
    #rfr_predicate = int(rfr_y_pred[idx])
    
    # 각 모델의 예측값을 배열에 삽입
    median_temp = np.append(median_temp, np.array([xgbregressor_predicate,dnn_predicate,nnls_predicate]))
    
    # median 값 사용
    mape = abs((value - np.median(median_temp)) / value) * 100
    
    # mean 값 사용
    # mape = abs((value - np.mean(median_temp)) / value) * 100
    
    mape_temp['xgb_pred'] = xgbregressor_predicate
    mape_temp['dnn_pred'] = dnn_predicate
    #mape_temp['linear_pred'] = linear_predicate
    mape_temp['nnls_pred'] = nnls_predicate
    #mape_temp['rfr_pred'] = rfr_predicate
    mape_temp['--best_pred--'] = np.median(median_temp)
    mape_temp['real'] = value
    mape_temp['mape'] = mape

    mape_list = np.append(mape_list,np.array([mape]))
    result_list[idx] = mape_temp

result_list_sort = sorted(result_list.values(), key=lambda x:(x['mape']), reverse=True)
result_list_sort
# Out:
# [{'xgb_pred': 31350,
#   'dnn_pred': 26505,
#   'nnls_pred': 218491,
#   '--best_pred--': 31350.0,
#   'real': 13334,
#   'mape': 135.1132443377831},
#  {'xgb_pred': 20013,
#   'dnn_pred': 42689,
#   'nnls_pred': 70150,
#   '--best_pred--': 42689.0,
#   'real': 20867,
#   'mape': 104.57660420760051},
#  {'xgb_pred': 10863,
#   'dnn_pred': 9794,
#   'nnls_pred': 101038,
#   '--best_pred--': 10863.0,
#   'real': 5543,
#   'mape': 95.97690781165434},
#  {'xgb_pred': 8688,
#   'dnn_pred': 8922,
#   'nnls_pred': 74673,
#   '--best_pred--': 8922.0,
#   'real': 4686,
#   'mape': 90.39692701664532},
#  {'xgb_pred': 11447,
#   'dnn_pred': 9801,
#   'nnls_pred': 72580,
#   '--best_pred--': 11447.0,
#   'real': 6487,
#   'mape': 76.46061353476183},
#  {'xgb_pred': 16447,
#   'dnn_pred': 17217,
#   'nnls_pred': 53829,
#   '--best_pred--': 17217.0,
#   'real': 10530,
#   'mape': 63.5042735042735},
#  {'xgb_pred': 12014,
#   'dnn_pred': 11743,
#   'nnls_pred': 131285,
#   '--best_pred--': 12014.0,
#   'real': 7369,
#   'mape': 63.03433301669155},
#  {'xgb_pred': 15921,
#   'dnn_pred': 20410,
#   'nnls_pred': 117358,
#   '--best_pred--': 20410.0,
#   'real': 12925,
#   'mape': 57.9110251450677},
#  {'xgb_pred': 56638,
#   'dnn_pred': 43977,
#   'nnls_pred': 204495,
#   '--best_pred--': 56638.0,
#   'real': 36559,
#   'mape': 54.922180584808125},
#  {'xgb_pred': 66179,
#   'dnn_pred': 59012,
#   'nnls_pred': 447492,
#   '--best_pred--': 66179.0,
#   'real': 44557,
#   'mape': 48.526606369369574},
#  {'xgb_pred': 27262,
#   'dnn_pred': 37235,
#   'nnls_pred': 206590,
#   '--best_pred--': 37235.0,
#   'real': 25294,
#   'mape': 47.20882422708943},
#  {'xgb_pred': 97800,
#   'dnn_pred': 132664,
#   'nnls_pred': 216507,
#   '--best_pred--': 132664.0,
#   'real': 92391,
#   'mape': 43.58974358974359},
#  {'xgb_pred': 10582,
#   'dnn_pred': 13948,
#   'nnls_pred': 75426,
#   '--best_pred--': 13948.0,
#   'real': 9862,
#   'mape': 41.43175826404381},
#  {'xgb_pred': 16843,
#   'dnn_pred': 14409,
#   'nnls_pred': 220454,
#   '--best_pred--': 16843.0,
#   'real': 28130,
#   'mape': 40.12442232492001},
#  {'xgb_pred': 13234,
#   'dnn_pred': 13021,
#   'nnls_pred': 111047,
#   '--best_pred--': 13234.0,
#   'real': 21956,
#   'mape': 39.724904354162874},
#  {'xgb_pred': 25415,
#   'dnn_pred': 25644,
#   'nnls_pred': 90798,
#   '--best_pred--': 25644.0,
#   'real': 18406,
#   'mape': 39.324133434749534},
#  {'xgb_pred': 43671,
#   'dnn_pred': 41093,
#   'nnls_pred': 152055,
#   '--best_pred--': 43671.0,
#   'real': 31380,
#   'mape': 39.168260038240916},
#  {'xgb_pred': 18921,
#   'dnn_pred': 17890,
#   'nnls_pred': 58127,
#   '--best_pred--': 18921.0,
#   'real': 13626,
#   'mape': 38.859533245266405},
#  {'xgb_pred': 11549,
#   'dnn_pred': 15045,
#   'nnls_pred': 121801,
#   '--best_pred--': 15045.0,
#   'real': 11087,
#   'mape': 35.699467845224135},
#  {'xgb_pred': 6577,
#   'dnn_pred': 7711,
#   'nnls_pred': 61691,
#   '--best_pred--': 7711.0,
#   'real': 5729,
#   'mape': 34.59591551754233},
#  {'xgb_pred': 19117,
#   'dnn_pred': 18456,
#   'nnls_pred': 72322,
#   '--best_pred--': 19117.0,
#   'real': 14229,
#   'mape': 34.35237894440931},
#  {'xgb_pred': 11901,
#   'dnn_pred': 12228,
#   'nnls_pred': 54327,
#   '--best_pred--': 12228.0,
#   'real': 18351,
#   'mape': 33.366029099231646},
#  {'xgb_pred': 15011,
#   'dnn_pred': 13121,
#   'nnls_pred': 103500,
#   '--best_pred--': 15011.0,
#   'real': 22416,
#   'mape': 33.034439685938615},
#  {'xgb_pred': 14896,
#   'dnn_pred': 18483,
#   'nnls_pred': 23880,
#   '--best_pred--': 18483.0,
#   'real': 14078,
#   'mape': 31.28995595965336},
#  {'xgb_pred': 21130,
#   'dnn_pred': 26213,
#   'nnls_pred': 153998,
#   '--best_pred--': 26213.0,
#   'real': 20022,
#   'mape': 30.920986914394167},
#  {'xgb_pred': 16147,
#   'dnn_pred': 19129,
#   'nnls_pred': 53568,
#   '--best_pred--': 19129.0,
#   'real': 14793,
#   'mape': 29.311160684107346},
#  {'xgb_pred': 4588913,
#   'dnn_pred': 6016652,
#   'nnls_pred': 3184085,
#   '--best_pred--': 4588913.0,
#   'real': 6344489,
#   'mape': 27.670880980327965},
#  {'xgb_pred': 31817,
#   'dnn_pred': 47230,
#   'nnls_pred': 256481,
#   '--best_pred--': 47230.0,
#   'real': 37097,
#   'mape': 27.314877213790872},
#  {'xgb_pred': 33531,
#   'dnn_pred': 38432,
#   'nnls_pred': 130303,
#   '--best_pred--': 38432.0,
#   'real': 30475,
#   'mape': 26.109926168990977},
#  {'xgb_pred': 29532,
#   'dnn_pred': 26946,
#   'nnls_pred': 109154,
#   '--best_pred--': 29532.0,
#   'real': 39551,
#   'mape': 25.331850016434476},
#  {'xgb_pred': 818302,
#   'dnn_pred': 689087,
#   'nnls_pred': 1037012,
#   '--best_pred--': 818302.0,
#   'real': 663222,
#   'mape': 23.382819025906862},
#  {'xgb_pred': 917715,
#   'dnn_pred': 766467,
#   'nnls_pred': 1063627,
#   '--best_pred--': 917715.0,
#   'real': 747211,
#   'mape': 22.81872188712425},
#  {'xgb_pred': 16050,
#   'dnn_pred': 15823,
#   'nnls_pred': 166274,
#   '--best_pred--': 16050.0,
#   'real': 13110,
#   'mape': 22.42562929061785},
#  {'xgb_pred': 30669,
#   'dnn_pred': 22019,
#   'nnls_pred': 182966,
#   '--best_pred--': 30669.0,
#   'real': 25090,
#   'mape': 22.23595057791949},
#  {'xgb_pred': 789992,
#   'dnn_pred': 969705,
#   'nnls_pred': 751918,
#   '--best_pred--': 789992.0,
#   'real': 1004111,
#   'mape': 21.32423606553459},
#  {'xgb_pred': 39034,
#   'dnn_pred': 59262,
#   'nnls_pred': 638674,
#   '--best_pred--': 59262.0,
#   'real': 49356,
#   'mape': 20.070508144906395},
#  {'xgb_pred': 11180,
#   'dnn_pred': 10592,
#   'nnls_pred': 25395,
#   '--best_pred--': 11180.0,
#   'real': 9352,
#   'mape': 19.546621043627034},
#  {'xgb_pred': 116616,
#   'dnn_pred': 139208,
#   'nnls_pred': 347915,
#   '--best_pred--': 139208.0,
#   'real': 116566,
#   'mape': 19.424188871540586},
#  {'xgb_pred': 516328,
#   'dnn_pred': 422901,
#   'nnls_pred': 711488,
#   '--best_pred--': 516328.0,
#   'real': 432681,
#   'mape': 19.332256327409798},
#  {'xgb_pred': 30905,
#   'dnn_pred': 25810,
#   'nnls_pred': 354974,
#   '--best_pred--': 30905.0,
#   'real': 38151,
#   'mape': 18.99294907079762},
#  {'xgb_pred': 35895,
#   'dnn_pred': 42997,
#   'nnls_pred': 177961,
#   '--best_pred--': 42997.0,
#   'real': 36328,
#   'mape': 18.357740585774057},
#  {'xgb_pred': 63961,
#   'dnn_pred': 71694,
#   'nnls_pred': 625445,
#   '--best_pred--': 71694.0,
#   'real': 87046,
#   'mape': 17.63665188521012},
#  {'xgb_pred': 36943,
#   'dnn_pred': 35369,
#   'nnls_pred': 87644,
#   '--best_pred--': 36943.0,
#   'real': 31577,
#   'mape': 16.993381258510944},
#  {'xgb_pred': 37593,
#   'dnn_pred': 38444,
#   'nnls_pred': 71589,
#   '--best_pred--': 38444.0,
#   'real': 46310,
#   'mape': 16.985532282444396},
#  {'xgb_pred': 15224,
#   'dnn_pred': 13391,
#   'nnls_pred': 60533,
#   '--best_pred--': 15224.0,
#   'real': 13113,
#   'mape': 16.098528178143827},
#  {'xgb_pred': 41866,
#   'dnn_pred': 41988,
#   'nnls_pred': 80702,
#   '--best_pred--': 41988.0,
#   'real': 49823,
#   'mape': 15.725668867791983},
#  {'xgb_pred': 1965102,
#   'dnn_pred': 2298348,
#   'nnls_pred': 896770,
#   '--best_pred--': 1965102.0,
#   'real': 2330004,
#   'mape': 15.661003157076125},
#  {'xgb_pred': 27397,
#   'dnn_pred': 29735,
#   'nnls_pred': 135076,
#   '--best_pred--': 29735.0,
#   'real': 25816,
#   'mape': 15.180508211961573},
#  {'xgb_pred': 34779,
#   'dnn_pred': 38035,
#   'nnls_pred': 141656,
#   '--best_pred--': 38035.0,
#   'real': 44795,
#   'mape': 15.090969974327493},
#  {'xgb_pred': 44129,
#   'dnn_pred': 39840,
#   'nnls_pred': 245126,
#   '--best_pred--': 44129.0,
#   'real': 51936,
#   'mape': 15.031962415280345},
#  {'xgb_pred': 78884,
#   'dnn_pred': 89168,
#   'nnls_pred': 327627,
#   '--best_pred--': 89168.0,
#   'real': 77551,
#   'mape': 14.979819731531506},
#  {'xgb_pred': 22572,
#   'dnn_pred': 21580,
#   'nnls_pred': 95415,
#   '--best_pred--': 22572.0,
#   'real': 19638,
#   'mape': 14.940421631530706},
#  {'xgb_pred': 37088,
#   'dnn_pred': 35537,
#   'nnls_pred': 162984,
#   '--best_pred--': 37088.0,
#   'real': 43430,
#   'mape': 14.602809118121115},
#  {'xgb_pred': 4043128,
#   'dnn_pred': 4599439,
#   'nnls_pred': 2422186,
#   '--best_pred--': 4043128.0,
#   'real': 4727456,
#   'mape': 14.47560802258128},
#  {'xgb_pred': 15625,
#   'dnn_pred': 15060,
#   'nnls_pred': 120858,
#   '--best_pred--': 15625.0,
#   'real': 13699,
#   'mape': 14.059420395649317},
#  {'xgb_pred': 34261,
#   'dnn_pred': 29526,
#   'nnls_pred': 120247,
#   '--best_pred--': 34261.0,
#   'real': 39679,
#   'mape': 13.65457798835656},
#  {'xgb_pred': 24901,
#   'dnn_pred': 18158,
#   'nnls_pred': 120782,
#   '--best_pred--': 24901.0,
#   'real': 28835,
#   'mape': 13.643142014912431},
#  {'xgb_pred': 4130592,
#   'dnn_pred': 4713185,
#   'nnls_pred': 2167444,
#   '--best_pred--': 4130592.0,
#   'real': 4777338,
#   'mape': 13.537790292418078},
#  {'xgb_pred': 58544,
#   'dnn_pred': 52338,
#   'nnls_pred': 262417,
#   '--best_pred--': 58544.0,
#   'real': 67247,
#   'mape': 12.941841271729594},
#  {'xgb_pred': 9752,
#   'dnn_pred': 7682,
#   'nnls_pred': 91031,
#   '--best_pred--': 9752.0,
#   'real': 8647,
#   'mape': 12.778998496588411},
#  {'xgb_pred': 18777,
#   'dnn_pred': 20845,
#   'nnls_pred': 105851,
#   '--best_pred--': 20845.0,
#   'real': 18527,
#   'mape': 12.51146974685594},
#  {'xgb_pred': 356617,
#   'dnn_pred': 380282,
#   'nnls_pred': 594149,
#   '--best_pred--': 380282.0,
#   'real': 432817,
#   'mape': 12.137924342158463},
#  {'xgb_pred': 15401,
#   'dnn_pred': 12656,
#   'nnls_pred': 58217,
#   '--best_pred--': 15401.0,
#   'real': 17374,
#   'mape': 11.356049269022678},
#  {'xgb_pred': 10801,
#   'dnn_pred': 15819,
#   'nnls_pred': 41711,
#   '--best_pred--': 15819.0,
#   'real': 14269,
#   'mape': 10.862709369962857},
#  {'xgb_pred': 143597,
#   'dnn_pred': 149422,
#   'nnls_pred': 334916,
#   '--best_pred--': 149422.0,
#   'real': 167215,
#   'mape': 10.640791794994469},
#  {'xgb_pred': 46439,
#   'dnn_pred': 52929,
#   'nnls_pred': 302738,
#   '--best_pred--': 52929.0,
#   'real': 58975,
#   'mape': 10.251801610852056},
#  {'xgb_pred': 35124,
#   'dnn_pred': 31307,
#   'nnls_pred': 101059,
#   '--best_pred--': 35124.0,
#   'real': 31902,
#   'mape': 10.099680270829415},
#  {'xgb_pred': 310086,
#   'dnn_pred': 287077,
#   'nnls_pred': 330264,
#   '--best_pred--': 310086.0,
#   'real': 281644,
#   'mape': 10.09856414480692},
#  {'xgb_pred': 10317,
#   'dnn_pred': 10745,
#   'nnls_pred': 34668,
#   '--best_pred--': 10745.0,
#   'real': 9760,
#   'mape': 10.092213114754097},
#  {'xgb_pred': 157937,
#   'dnn_pred': 143143,
#   'nnls_pred': 222275,
#   '--best_pred--': 157937.0,
#   'real': 143737,
#   'mape': 9.879154288735677},
#  {'xgb_pred': 848938,
#   'dnn_pred': 763215,
#   'nnls_pred': 1965835,
#   '--best_pred--': 848938.0,
#   'real': 773234,
#   'mape': 9.790567926397442},
#  {'xgb_pred': 1431633,
#   'dnn_pred': 1407171,
#   'nnls_pred': 1079957,
#   '--best_pred--': 1407171.0,
#   'real': 1558644,
#   'mape': 9.718255098662684},
#  {'xgb_pred': 28840,
#   'dnn_pred': 29545,
#   'nnls_pred': 90031,
#   '--best_pred--': 29545.0,
#   'real': 32690,
#   'mape': 9.620679106760477},
#  {'xgb_pred': 54003,
#   'dnn_pred': 67338,
#   'nnls_pred': 182235,
#   '--best_pred--': 67338.0,
#   'real': 74495,
#   'mape': 9.607356198402577},
#  {'xgb_pred': 33126,
#   'dnn_pred': 29631,
#   'nnls_pred': 111314,
#   '--best_pred--': 33126.0,
#   'real': 30261,
#   'mape': 9.467631605036186},
#  {'xgb_pred': 11303,
#   'dnn_pred': 12333,
#   'nnls_pred': 78829,
#   '--best_pred--': 12333.0,
#   'real': 11269,
#   'mape': 9.4418315733428},
#  {'xgb_pred': 61958,
#   'dnn_pred': 69496,
#   'nnls_pred': 129493,
#   '--best_pred--': 69496.0,
#   'real': 63564,
#   'mape': 9.332326474104839},
#  {'xgb_pred': 412112,
#   'dnn_pred': 402280,
#   'nnls_pred': 483290,
#   '--best_pred--': 412112.0,
#   'real': 453645,
#   'mape': 9.155396841142304},
#  {'xgb_pred': 1596636,
#   'dnn_pred': 1711533,
#   'nnls_pred': 1279016,
#   '--best_pred--': 1596636.0,
#   'real': 1754542,
#   'mape': 8.999841554092178},
#  {'xgb_pred': 70726,
#   'dnn_pred': 76387,
#   'nnls_pred': 216000,
#   '--best_pred--': 76387.0,
#   'real': 70154,
#   'mape': 8.884739287852438},
#  {'xgb_pred': 401841,
#   'dnn_pred': 390561,
#   'nnls_pred': 687914,
#   '--best_pred--': 401841.0,
#   'real': 369161,
#   'mape': 8.85250608812957},
#  {'xgb_pred': 28083,
#   'dnn_pred': 24801,
#   'nnls_pred': 106279,
#   '--best_pred--': 28083.0,
#   'real': 30792,
#   'mape': 8.797739672642244},
#  {'xgb_pred': 52972,
#   'dnn_pred': 59673,
#   'nnls_pred': 161078,
#   '--best_pred--': 59673.0,
#   'real': 65382,
#   'mape': 8.731761035147288},
#  {'xgb_pred': 1184040,
#   'dnn_pred': 1100164,
#   'nnls_pred': 1287063,
#   '--best_pred--': 1184040.0,
#   'real': 1089733,
#   'mape': 8.654138215507835},
#  {'xgb_pred': 50669,
#   'dnn_pred': 49179,
#   'nnls_pred': 200123,
#   '--best_pred--': 50669.0,
#   'real': 46710,
#   'mape': 8.475701134660673},
#  {'xgb_pred': 861423,
#   'dnn_pred': 940416,
#   'nnls_pred': 783118,
#   '--best_pred--': 861423.0,
#   'real': 940945,
#   'mape': 8.4512909893777},
#  {'xgb_pred': 154519,
#   'dnn_pred': 163593,
#   'nnls_pred': 274638,
#   '--best_pred--': 163593.0,
#   'real': 151100,
#   'mape': 8.268034414295169},
#  {'xgb_pred': 55542,
#   'dnn_pred': 59929,
#   'nnls_pred': 211350,
#   '--best_pred--': 59929.0,
#   'real': 55405,
#   'mape': 8.16532803898565},
#  {'xgb_pred': 89729,
#   'dnn_pred': 101949,
#   'nnls_pred': 283739,
#   '--best_pred--': 101949.0,
#   'real': 94388,
#   'mape': 8.010552188837563},
#  {'xgb_pred': 117488,
#   'dnn_pred': 145831,
#   'nnls_pred': 251649,
#   '--best_pred--': 145831.0,
#   'real': 135060,
#   'mape': 7.974974085591589},
#  {'xgb_pred': 26971,
#   'dnn_pred': 24111,
#   'nnls_pred': 176315,
#   '--best_pred--': 26971.0,
#   'real': 29229,
#   'mape': 7.725204420267542},
#  {'xgb_pred': 16875,
#   'dnn_pred': 18081,
#   'nnls_pred': 78571,
#   '--best_pred--': 18081.0,
#   'real': 16821,
#   'mape': 7.490636704119851},
#  {'xgb_pred': 23969,
#   'dnn_pred': 22674,
#   'nnls_pred': 177588,
#   '--best_pred--': 23969.0,
#   'real': 25881,
#   'mape': 7.387658900351609},
#  {'xgb_pred': 17260,
#   'dnn_pred': 18371,
#   'nnls_pred': 123225,
#   '--best_pred--': 18371.0,
#   'real': 19803,
#   'mape': 7.231227591779023},
#  {'xgb_pred': 116565,
#   'dnn_pred': 116140,
#   'nnls_pred': 291659,
#   '--best_pred--': 116565.0,
#   'real': 109182,
#   'mape': 6.7621036434577135},
#  {'xgb_pred': 27912,
#   'dnn_pred': 29247,
#   'nnls_pred': 54195,
#   '--best_pred--': 29247.0,
#   'real': 31359,
#   'mape': 6.734908638668324},
#  {'xgb_pred': 49299,
#   'dnn_pred': 53846,
#   'nnls_pred': 246902,
#   '--best_pred--': 53846.0,
#   'real': 50508,
#   'mape': 6.608854042923894},
#  {'xgb_pred': 1323777,
#   'dnn_pred': 1387369,
#   'nnls_pred': 1896579,
#   '--best_pred--': 1387369.0,
#   'real': 1304262,
#   'mape': 6.371955941367609},
#  {'xgb_pred': 173347,
#   'dnn_pred': 175882,
#   'nnls_pred': 272956,
#   '--best_pred--': 175882.0,
#   'real': 165377,
#   'mape': 6.352152959601395},
#  {'xgb_pred': 23415,
#   'dnn_pred': 17903,
#   'nnls_pred': 114807,
#   '--best_pred--': 23415.0,
#   'real': 22029,
#   'mape': 6.291706387035272},
#  {'xgb_pred': 50749,
#   'dnn_pred': 56006,
#   'nnls_pred': 224053,
#   '--best_pred--': 56006.0,
#   'real': 52737,
#   'mape': 6.19868403587614},
#  {'xgb_pred': 10078,
#   'dnn_pred': 11781,
#   'nnls_pred': 16425,
#   '--best_pred--': 11781.0,
#   'real': 11100,
#   'mape': 6.135135135135135},
#  {'xgb_pred': 161627,
#   'dnn_pred': 182401,
#   'nnls_pred': 429942,
#   '--best_pred--': 182401.0,
#   'real': 172021,
#   'mape': 6.034146993681004},
#  {'xgb_pred': 528306,
#   'dnn_pred': 537099,
#   'nnls_pred': 523783,
#   '--best_pred--': 528306.0,
#   'real': 560004,
#   'mape': 5.660316712023485},
#  {'xgb_pred': 715191,
#   'dnn_pred': 717204,
#   'nnls_pred': 1152422,
#   '--best_pred--': 717204.0,
#   'real': 759959,
#   'mape': 5.62596140054924},
#  {'xgb_pred': 55740,
#   'dnn_pred': 69992,
#   'nnls_pred': 141309,
#   '--best_pred--': 69992.0,
#   'real': 66346,
#   'mape': 5.495433032888193},
#  {'xgb_pred': 54103,
#   'dnn_pred': 35418,
#   'nnls_pred': 755286,
#   '--best_pred--': 54103.0,
#   'real': 51306,
#   'mape': 5.451604100884887},
#  {'xgb_pred': 127402,
#   'dnn_pred': 144159,
#   'nnls_pred': 292077,
#   '--best_pred--': 144159.0,
#   'real': 136734,
#   'mape': 5.430251437096844},
#  {'xgb_pred': 40626,
#   'dnn_pred': 41344,
#   'nnls_pred': 85803,
#   '--best_pred--': 41344.0,
#   'real': 43682,
#   'mape': 5.352319033011309},
#  {'xgb_pred': 20608,
#   'dnn_pred': 19796,
#   'nnls_pred': 109903,
#   '--best_pred--': 20608.0,
#   'real': 19563,
#   'mape': 5.341716505648418},
#  {'xgb_pred': 25059,
#   'dnn_pred': 25851,
#   'nnls_pred': 48639,
#   '--best_pred--': 25851.0,
#   'real': 27256,
#   'mape': 5.154828294687408},
#  {'xgb_pred': 102281,
#   'dnn_pred': 96874,
#   'nnls_pred': 113580,
#   '--best_pred--': 102281.0,
#   'real': 97298,
#   'mape': 5.121379678924541},
#  {'xgb_pred': 93524,
#   'dnn_pred': 79945,
#   'nnls_pred': 303168,
#   '--best_pred--': 93524.0,
#   'real': 98308,
#   'mape': 4.8663384465150346},
#  {'xgb_pred': 57102,
#   'dnn_pred': 61114,
#   'nnls_pred': 134730,
#   '--best_pred--': 61114.0,
#   'real': 64162,
#   'mape': 4.750475359246907},
#  {'xgb_pred': 94954,
#   'dnn_pred': 95574,
#   'nnls_pred': 226241,
#   '--best_pred--': 95574.0,
#   'real': 91244,
#   'mape': 4.745517513480339},
#  {'xgb_pred': 339961,
#   'dnn_pred': 356798,
#   'nnls_pred': 428193,
#   '--best_pred--': 356798.0,
#   'real': 341110,
#   'mape': 4.599102928674035},
#  {'xgb_pred': 15465,
#   'dnn_pred': 15864,
#   'nnls_pred': 134204,
#   '--best_pred--': 15864.0,
#   'real': 16617,
#   'mape': 4.53150388156707},
#  {'xgb_pred': 133208,
#   'dnn_pred': 145846,
#   'nnls_pred': 271785,
#   '--best_pred--': 145846.0,
#   'real': 139591,
#   'mape': 4.480947912114678},
#  {'xgb_pred': 288184,
#   'dnn_pred': 295825,
#   'nnls_pred': 246539,
#   '--best_pred--': 288184.0,
#   'real': 301658,
#   'mape': 4.466647660595774},
#  {'xgb_pred': 282610,
#   'dnn_pred': 268237,
#   'nnls_pred': 479057,
#   '--best_pred--': 282610.0,
#   'real': 270598,
#   'mape': 4.439057199240201},
#  {'xgb_pred': 1141187,
#   'dnn_pred': 1103972,
#   'nnls_pred': 818621,
#   '--best_pred--': 1103972.0,
#   'real': 1154837,
#   'mape': 4.404517693839044},
#  {'xgb_pred': 101171,
#   'dnn_pred': 99529,
#   'nnls_pred': 188381,
#   '--best_pred--': 101171.0,
#   'real': 96990,
#   'mape': 4.310753685947004},
#  {'xgb_pred': 42705,
#   'dnn_pred': 52067,
#   'nnls_pred': 138402,
#   '--best_pred--': 52067.0,
#   'real': 49944,
#   'mape': 4.250760852154413},
#  {'xgb_pred': 198475,
#   'dnn_pred': 193689,
#   'nnls_pred': 395737,
#   '--best_pred--': 198475.0,
#   'real': 190442,
#   'mape': 4.218082145745161},
#  {'xgb_pred': 124644,
#   'dnn_pred': 119360,
#   'nnls_pred': 235247,
#   '--best_pred--': 124644.0,
#   'real': 119665,
#   'mape': 4.160782183595871},
#  {'xgb_pred': 70974,
#   'dnn_pred': 65723,
#   'nnls_pred': 179538,
#   '--best_pred--': 70974.0,
#   'real': 68167,
#   'mape': 4.117828274678363},
#  {'xgb_pred': 34783,
#   'dnn_pred': 32675,
#   'nnls_pred': 70502,
#   '--best_pred--': 34783.0,
#   'real': 36276,
#   'mape': 4.115668761715735},
#  {'xgb_pred': 18885,
#   'dnn_pred': 18979,
#   'nnls_pred': 90545,
#   '--best_pred--': 18979.0,
#   'real': 18245,
#   'mape': 4.023020005480954},
#  {'xgb_pred': 185304,
#   'dnn_pred': 187985,
#   'nnls_pred': 274583,
#   '--best_pred--': 187985.0,
#   'real': 181070,
#   'mape': 3.818965041144309},
#  {'xgb_pred': 207843,
#   'dnn_pred': 208385,
#   'nnls_pred': 380731,
#   '--best_pred--': 208385.0,
#   'real': 216479,
#   'mape': 3.7389307969826175},
#  {'xgb_pred': 46192,
#   'dnn_pred': 40207,
#   'nnls_pred': 510812,
#   '--best_pred--': 46192.0,
#   'real': 47983,
#   'mape': 3.7325719525665337},
#  {'xgb_pred': 31071,
#   'dnn_pred': 29012,
#   'nnls_pred': 72701,
#   '--best_pred--': 31071.0,
#   'real': 32273,
#   'mape': 3.724475567812103},
#  {'xgb_pred': 75047,
#   'dnn_pred': 73869,
#   'nnls_pred': 464490,
#   '--best_pred--': 75047.0,
#   'real': 77798,
#   'mape': 3.5360806190390495},
#  {'xgb_pred': 648718,
#   'dnn_pred': 666825,
#   'nnls_pred': 618602,
#   '--best_pred--': 648718.0,
#   'real': 672265,
#   'mape': 3.50263660907529},
#  {'xgb_pred': 881560,
#   'dnn_pred': 887043,
#   'nnls_pred': 1288106,
#   '--best_pred--': 887043.0,
#   'real': 917973,
#   'mape': 3.3693801451676686},
#  {'xgb_pred': 117055,
#   'dnn_pred': 116588,
#   'nnls_pred': 281090,
#   '--best_pred--': 117055.0,
#   'real': 121029,
#   'mape': 3.2835105635839343},
#  {'xgb_pred': 42795,
#   'dnn_pred': 43087,
#   'nnls_pred': 145278,
#   '--best_pred--': 43087.0,
#   'real': 41750,
#   'mape': 3.202395209580838},
#  {'xgb_pred': 657666,
#   'dnn_pred': 610473,
#   'nnls_pred': 467442,
#   '--best_pred--': 610473.0,
#   'real': 630627,
#   'mape': 3.1958669704912728},
#  {'xgb_pred': 58146,
#   'dnn_pred': 62189,
#   'nnls_pred': 120984,
#   '--best_pred--': 62189.0,
#   'real': 60379,
#   'mape': 2.9977309991884598},
#  {'xgb_pred': 122680,
#   'dnn_pred': 132137,
#   'nnls_pred': 327383,
#   '--best_pred--': 132137.0,
#   'real': 128294,
#   'mape': 2.995463544670834},
#  {'xgb_pred': 557907,
#   'dnn_pred': 581016,
#   'nnls_pred': 985798,
#   '--best_pred--': 581016.0,
#   'real': 598523,
#   'mape': 2.9250337915167837},
#  {'xgb_pred': 52865,
#   'dnn_pred': 54888,
#   'nnls_pred': 98645,
#   '--best_pred--': 54888.0,
#   'real': 53416,
#   'mape': 2.755728620638011},
#  {'xgb_pred': 81408,
#   'dnn_pred': 92289,
#   'nnls_pred': 130811,
#   '--best_pred--': 92289.0,
#   'real': 89910,
#   'mape': 2.6459793126459794},
#  {'xgb_pred': 1192355,
#   'dnn_pred': 1266857,
#   'nnls_pred': 1140033,
#   '--best_pred--': 1192355.0,
#   'real': 1224120,
#   'mape': 2.59492533411757},
#  {'xgb_pred': 773476,
#   'dnn_pred': 834149,
#   'nnls_pred': 873216,
#   '--best_pred--': 834149.0,
#   'real': 813244,
#   'mape': 2.5705692264560205},
#  {'xgb_pred': 53403,
#   'dnn_pred': 55836,
#   'nnls_pred': 116625,
#   '--best_pred--': 55836.0,
#   'real': 54445,
#   'mape': 2.5548718890623565},
#  {'xgb_pred': 291770,
#   'dnn_pred': 313342,
#   'nnls_pred': 570235,
#   '--best_pred--': 313342.0,
#   'real': 305757,
#   'mape': 2.480728159944008},
#  {'xgb_pred': 186744,
#   'dnn_pred': 205365,
#   'nnls_pred': 716452,
#   '--best_pred--': 205365.0,
#   'real': 210460,
#   'mape': 2.42088757958757},
#  {'xgb_pred': 30805,
#   'dnn_pred': 30275,
#   'nnls_pred': 69099,
#   '--best_pred--': 30805.0,
#   'real': 31557,
#   'mape': 2.3829895110435086},
#  {'xgb_pred': 183747,
#   'dnn_pred': 186633,
#   'nnls_pred': 343256,
#   '--best_pred--': 186633.0,
#   'real': 190964,
#   'mape': 2.2679667371860663},
#  {'xgb_pred': 632633,
#   'dnn_pred': 648148,
#   'nnls_pred': 658646,
#   '--best_pred--': 648148.0,
#   'real': 633867,
#   'mape': 2.2529962910200405},
#  {'xgb_pred': 110676,
#   'dnn_pred': 123274,
#   'nnls_pred': 444324,
#   '--best_pred--': 123274.0,
#   'real': 126101,
#   'mape': 2.2418537521510533},
#  {'xgb_pred': 253817,
#   'dnn_pred': 270354,
#   'nnls_pred': 432044,
#   '--best_pred--': 270354.0,
#   'real': 276319,
#   'mape': 2.1587368222959693},
#  {'xgb_pred': 70539,
#   'dnn_pred': 76965,
#   'nnls_pred': 251820,
#   '--best_pred--': 76965.0,
#   'real': 78642,
#   'mape': 2.132448310063325},
#  {'xgb_pred': 360243,
#   'dnn_pred': 367750,
#   'nnls_pred': 898093,
#   '--best_pred--': 367750.0,
#   'real': 360627,
#   'mape': 1.9751710215818559},
#  {'xgb_pred': 1584629,
#   'dnn_pred': 1561254,
#   'nnls_pred': 1510688,
#   '--best_pred--': 1561254.0,
#   'real': 1533202,
#   'mape': 1.8296349730824772},
#  {'xgb_pred': 202700,
#   'dnn_pred': 226733,
#   'nnls_pred': 378666,
#   '--best_pred--': 226733.0,
#   'real': 222732,
#   'mape': 1.796329220767559},
#  {'xgb_pred': 67471,
#   'dnn_pred': 67641,
#   'nnls_pred': 130903,
#   '--best_pred--': 67641.0,
#   'real': 68873,
#   'mape': 1.7887996747636956},
#  {'xgb_pred': 1324266,
#   'dnn_pred': 1357590,
#   'nnls_pred': 1000461,
#   '--best_pred--': 1324266.0,
#   'real': 1347968,
#   'mape': 1.7583503465957648},
#  {'xgb_pred': 37315,
#   'dnn_pred': 38679,
#   'nnls_pred': 97905,
#   '--best_pred--': 38679.0,
#   'real': 38015,
#   'mape': 1.7466789425226885},
#  {'xgb_pred': 19693,
#   'dnn_pred': 21177,
#   'nnls_pred': 79933,
#   '--best_pred--': 21177.0,
#   'real': 21553,
#   'mape': 1.7445367234259732},
#  {'xgb_pred': 65962,
#   'dnn_pred': 67041,
#   'nnls_pred': 166484,
#   '--best_pred--': 67041.0,
#   'real': 65894,
#   'mape': 1.7406744164870855},
#  {'xgb_pred': 287549,
#   'dnn_pred': 247713,
#   'nnls_pred': 651972,
#   '--best_pred--': 287549.0,
#   'real': 292271,
#   'mape': 1.6156238559419172},
#  {'xgb_pred': 282025,
#   'dnn_pred': 284325,
#   'nnls_pred': 350248,
#   '--best_pred--': 284325.0,
#   'real': 279834,
#   'mape': 1.6048800360213555},
#  {'xgb_pred': 106622,
#   'dnn_pred': 136002,
#   'nnls_pred': 299139,
#   '--best_pred--': 136002.0,
#   'real': 133872,
#   'mape': 1.5910720688418787},
#  {'xgb_pred': 348782,
#   'dnn_pred': 341449,
#   'nnls_pred': 504828,
#   '--best_pred--': 348782.0,
#   'real': 343975,
#   'mape': 1.3974852823606367},
#  {'xgb_pred': 291152,
#   'dnn_pred': 281443,
#   'nnls_pred': 733118,
#   '--best_pred--': 291152.0,
#   'real': 295223,
#   'mape': 1.3789576015418854},
#  {'xgb_pred': 578850,
#   'dnn_pred': 614442,
#   'nnls_pred': 1029538,
#   '--best_pred--': 614442.0,
#   'real': 622865,
#   'mape': 1.3522994549380685},
#  {'xgb_pred': 2771960,
#   'dnn_pred': 2846248,
#   'nnls_pred': 2220494,
#   '--best_pred--': 2771960.0,
#   'real': 2803943,
#   'mape': 1.1406437292056222},
#  {'xgb_pred': 117815,
#   'dnn_pred': 121915,
#   'nnls_pred': 270470,
#   '--best_pred--': 121915.0,
#   'real': 120592,
#   'mape': 1.0970877006766617},
#  {'xgb_pred': 447009,
#   'dnn_pred': 442231,
#   'nnls_pred': 552609,
#   '--best_pred--': 447009.0,
#   'real': 451656,
#   'mape': 1.0288803868430842},
#  {'xgb_pred': 1550584,
#   'dnn_pred': 1299278,
#   'nnls_pred': 1231526,
#   '--best_pred--': 1299278.0,
#   'real': 1286669,
#   'mape': 0.9799723161123801},
#  {'xgb_pred': 703015,
#   'dnn_pred': 711797,
#   'nnls_pred': 764710,
#   '--best_pred--': 711797.0,
#   'real': 705863,
#   'mape': 0.840673048452745},
#  {'xgb_pred': 92514,
#   'dnn_pred': 93844,
#   'nnls_pred': 357618,
#   '--best_pred--': 93844.0,
#   'real': 93092,
#   'mape': 0.8078030335582005},
#  {'xgb_pred': 200020,
#   'dnn_pred': 246484,
#   'nnls_pred': 354074,
#   '--best_pred--': 246484.0,
#   'real': 244678,
#   'mape': 0.7381129484465297},
#  {'xgb_pred': 38684,
#   'dnn_pred': 42100,
#   'nnls_pred': 148157,
#   '--best_pred--': 42100.0,
#   'real': 42413,
#   'mape': 0.7379812793247353},
#  {'xgb_pred': 2398887,
#   'dnn_pred': 2259361,
#   'nnls_pred': 2073157,
#   '--best_pred--': 2259361.0,
#   'real': 2243000,
#   'mape': 0.7294248773963442},
#  {'xgb_pred': 41819,
#   'dnn_pred': 45116,
#   'nnls_pred': 194147,
#   '--best_pred--': 45116.0,
#   'real': 44802,
#   'mape': 0.7008615686799696},
#  {'xgb_pred': 881756,
#   'dnn_pred': 848635,
#   'nnls_pred': 1253699,
#   '--best_pred--': 881756.0,
#   'real': 877427,
#   'mape': 0.49337437758354824},
#  {'xgb_pred': 79044,
#   'dnn_pred': 79051,
#   'nnls_pred': 233436,
#   '--best_pred--': 79051.0,
#   'real': 78718,
#   'mape': 0.42302904037196065},
#  {'xgb_pred': 189260,
#   'dnn_pred': 212141,
#   'nnls_pred': 368010,
#   '--best_pred--': 212141.0,
#   'real': 211421,
#   'mape': 0.3405527360101409},
#  {'xgb_pred': 138503,
#   'dnn_pred': 144532,
#   'nnls_pred': 283734,
#   '--best_pred--': 144532.0,
#   'real': 144060,
#   'mape': 0.327641260585867},
#  {'xgb_pred': 194237,
#   'dnn_pred': 196987,
#   'nnls_pred': 279237,
#   '--best_pred--': 196987.0,
#   'real': 196380,
#   'mape': 0.30909461248599657},
#  {'xgb_pred': 605288,
#   'dnn_pred': 629823,
#   'nnls_pred': 1483909,
#   '--best_pred--': 629823.0,
#   'real': 627928,
#   'mape': 0.3017861920474959},
#  {'xgb_pred': 462973,
#   'dnn_pred': 451991,
#   'nnls_pred': 680108,
#   '--best_pred--': 462973.0,
#   'real': 464198,
#   'mape': 0.2638960098923304},
#  {'xgb_pred': 125644,
#   'dnn_pred': 128582,
#   'nnls_pred': 272777,
#   '--best_pred--': 128582.0,
#   'real': 128247,
#   'mape': 0.26121468728313335},
#  {'xgb_pred': 259729,
#   'dnn_pred': 258859,
#   'nnls_pred': 552607,
#   '--best_pred--': 259729.0,
#   'real': 260394,
#   'mape': 0.2553822284691659},
#  {'xgb_pred': 10589,
#   'dnn_pred': 10940,
#   'nnls_pred': 90401,
#   '--best_pred--': 10940.0,
#   'real': 10965,
#   'mape': 0.22799817601459188},
#  {'xgb_pred': 128956,
#   'dnn_pred': 130600,
#   'nnls_pred': 274367,
#   '--best_pred--': 130600.0,
#   'real': 130844,
#   'mape': 0.1864816116902571},
#  {'xgb_pred': 757329,
#   'dnn_pred': 772353,
#   'nnls_pred': 755824,
#   '--best_pred--': 757329.0,
#   'real': 758334,
#   'mape': 0.1325273560199068},
#  {'xgb_pred': 94270,
#   'dnn_pred': 104088,
#   'nnls_pred': 278279,
#   '--best_pred--': 104088.0,
#   'real': 103961,
#   'mape': 0.12216119506353344},
#  {'xgb_pred': 2442456,
#   'dnn_pred': 2520661,
#   'nnls_pred': 2630535,
#   '--best_pred--': 2520661.0,
#   'real': 2523708,
#   'mape': 0.12073504541729868}]

# %%
# 최적의 pred을 골라냈을 때 mape 평균
print(np.mean(mape_list))
# Out:
# 13.567313292147338
