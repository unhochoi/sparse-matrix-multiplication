# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import ReLU
from tensorflow.keras.optimizers import Adam

# %%
# 1727, 191
train = pd.read_csv('/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/d-optimal/d-optimal-of-spmm/train-test-csv/1727-nonsquare-train-from-1918-nonsquare-spmm-over-3s.csv')
test = pd.read_csv('/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/d-optimal/d-optimal-of-spmm/train-test-csv/191-nonsquare-test-from-1918-nonsquare-spmm-over-3s.csv')

# %%
# feature 1개 추가

# Train + Valid
X_train = train[['lr','lc','rc','ld','rd','lnnz','rnnz','lr*lc','lc*rc','lr*rc','lr*lc*rc','ld*rd','lr*rc*ld*rd','lr*lc*rc*ld*rd','lnnz*rnnz']] 
y_train = train['bz_smdm']

# Test
X_test = test[['lr','lc','rc','ld','rd','lnnz','rnnz','lr*lc','lc*rc','lr*rc','lr*lc*rc','ld*rd','lr*rc*ld*rd','lr*lc*rc*ld*rd','lnnz*rnnz']] 
y_test = test['bz_smdm']

# %%
#  feature 4개 추가 (xgbregressor 용 feature)

# Train + Valid
X_train_v2 = train[['lr','lc','rc','ld','rd','lnnz','rnnz','lr*lc','lc*rc','lr*rc','lr*lc*rc','ld*rd','lr*rc*ld*rd','lr*lc*rc*ld*rd','lnnz*rnnz','lnnz+rnnz','lnnz+lc*rc','lr*lc+lc*rc']] 

# Test
X_test_v2 = test[['lr','lc','rc','ld','rd','lnnz','rnnz','lr*lc','lc*rc','lr*rc','lr*lc*rc','ld*rd','lr*rc*ld*rd','lr*lc*rc*ld*rd','lnnz*rnnz','lnnz+rnnz','lnnz+lc*rc','lr*lc+lc*rc']]

# %%
# 데이터 표준화(Standardization)
from sklearn.preprocessing import StandardScaler

# 변형 객체 생성
std_scaler = StandardScaler()

# 훈련데이터의 모수 분포 저장
std_scaler.fit(X_train)

# 훈련 데이터 스케일링
X_train_scaled = std_scaler.transform(X_train)

# 테스트 데이터의 스케일링
X_test_scaled = std_scaler.transform(X_test)

# %%
from sklearn.metrics import mean_squared_error

def mape_error(y_test, y_pred):
    y_test, y_pred = np.array(y_test), np.array(y_pred)
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

def rmse_error(y_true, y_pred):
    rmse = np.sqrt(np.mean(np.square(y_pred - y_true))) 
    return rmse

# %% [markdown]
# ### Xgbregressor

# %%
import xgboost as xgb

# Train + Valid cross-validation을 거친, 최적의 하이퍼파라미터를 사용
xgbregressor_model = xgb.XGBRegressor(
objective = 'reg:squarederror',
max_depth=int(14),
learning_rate=0.02398298537228648,
n_estimators=int(149),
subsample=0.5732030368686496,
reg_lambda = 0.36548495335549436,    
n_jobs=-1
                             )
# 모델 훈련
xgbregressor_model.fit(X_train_v2, y_train)
# Out:
# XGBRegressor(learning_rate=0.02398298537228648, max_depth=14, n_estimators=149,
#              n_jobs=-1, objective='reg:squarederror',
#              reg_lambda=0.36548495335549436, subsample=0.5732030368686496)

# %% [markdown]
# ### dnn

# %%
# 모델 생성
def build_model():

    model=Sequential()

    model.add(Dense(256, activation="relu", input_shape=(X_train.shape[1],)))  
    model.add(Dense(128, activation="relu"))
    model.add(Dense(64, activation="relu"))
    model.add(Dense(32, activation="relu"))
    model.add(Dense(1))
    
    optimizer = Adam(lr=0.01)
    
    model.compile(optimizer=optimizer ,
                  loss='mape',
                  metrics=['mape'])
    return model

dnn_model = build_model()

# %%
# 에포크가 끝날 때마다 점(.)을 출력해 훈련 진행 과정을 표시합니다
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end='')

early_stop = keras.callbacks.EarlyStopping(monitor='val_mape', patience=150)

EPOCHS = 100000

dnn_model.fit(X_train_scaled, 
                y_train,
                epochs=EPOCHS, 
                validation_split = 0.1, 
                verbose =0, 
                callbacks=[early_stop, PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ...................

# %% [markdown]
# ### rfr

# %%
from sklearn.ensemble import RandomForestRegressor

rfr_model = RandomForestRegressor(
criterion='mse',
max_depth=24,
min_samples_leaf=2, 
min_samples_split=4, 
n_estimators=800
)

rfr_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=24, min_samples_leaf=2, min_samples_split=4,
#                       n_estimators=800)

# %% [markdown]
# ### test

# %%
xgbregressor_y_pred = xgbregressor_model.predict(X_test_v2)
dnn_y_pred = dnn_model.predict(X_test_scaled).reshape(-1,)
rfr_y_pred = rfr_model.predict(X_test)

# %%
print(mape_error(y_test,xgbregressor_y_pred))
print(mape_error(y_test,dnn_y_pred))
print(mape_error(y_test,rfr_y_pred))
# Out:
# 12.307202381784455
# 13.613920626331275
# 15.30806246327954

# %%
result_list = {}
mape_list = np.array([])

# 예측값, 실제값을 확인하며 mape 계산 후 mape_list에 삽입 
for idx,value in enumerate(y_test):
    mape_temp = {}
    median_temp = np.array([])
    
    # 각 모델의 예측값
    xgbregressor_predicate = int(xgbregressor_y_pred[idx])
    dnn_predicate = int(dnn_y_pred[idx])
    rfr_predicate = int(rfr_y_pred[idx])
    
    # 각 모델의 예측값을 배열에 삽입
    median_temp = np.append(median_temp, np.array([xgbregressor_predicate,dnn_predicate,rfr_predicate]))
    
    # median 값 사용
    mape = abs((value - np.median(median_temp)) / value) * 100
    
    # mean 값 사용
    # mape = abs((value - np.mean(median_temp)) / value) * 100
    
    mape_temp['xgb_pred'] = xgbregressor_predicate
    mape_temp['dnn_pred'] = dnn_predicate
    mape_temp['rfr_pred'] = rfr_predicate
    mape_temp['best_pred'] = np.median(median_temp)
    mape_temp['real'] = value
    mape_temp['mape'] = mape

    mape_list = np.append(mape_list,np.array([mape]))
    result_list[idx] = mape_temp

result_list_sort = sorted(result_list.values(), key=lambda x:(x['mape']), reverse=True)
result_list_sort
# Out:
# [{'xgb_pred': 31350,
#   'dnn_pred': 28232,
#   'rfr_pred': 33333,
#   'best_pred': 31350.0,
#   'real': 13334,
#   'mape': 135.1132443377831},
#  {'xgb_pred': 10863,
#   'dnn_pred': 9374,
#   'rfr_pred': 12179,
#   'best_pred': 10863.0,
#   'real': 5543,
#   'mape': 95.97690781165434},
#  {'xgb_pred': 12014,
#   'dnn_pred': 13159,
#   'rfr_pred': 13424,
#   'best_pred': 13159.0,
#   'real': 7369,
#   'mape': 78.57239788302348},
#  {'xgb_pred': 8688,
#   'dnn_pred': 8209,
#   'rfr_pred': 7767,
#   'best_pred': 8209.0,
#   'real': 4686,
#   'mape': 75.18139137857447},
#  {'xgb_pred': 11447,
#   'dnn_pred': 10475,
#   'rfr_pred': 11062,
#   'best_pred': 11062.0,
#   'real': 6487,
#   'mape': 70.52566671805148},
#  {'xgb_pred': 16447,
#   'dnn_pred': 18748,
#   'rfr_pred': 16597,
#   'best_pred': 16597.0,
#   'real': 10530,
#   'mape': 57.616334283000946},
#  {'xgb_pred': 56638,
#   'dnn_pred': 44586,
#   'rfr_pred': 67593,
#   'best_pred': 56638.0,
#   'real': 36559,
#   'mape': 54.922180584808125},
#  {'xgb_pred': 66179,
#   'dnn_pred': 65815,
#   'rfr_pred': 72811,
#   'best_pred': 66179.0,
#   'real': 44557,
#   'mape': 48.526606369369574},
#  {'xgb_pred': 25415,
#   'dnn_pred': 26190,
#   'rfr_pred': 26387,
#   'best_pred': 26190.0,
#   'real': 18406,
#   'mape': 42.290557426926},
#  {'xgb_pred': 15921,
#   'dnn_pred': 20958,
#   'rfr_pred': 18301,
#   'best_pred': 18301.0,
#   'real': 12925,
#   'mape': 41.59381044487427},
#  {'xgb_pred': 16843,
#   'dnn_pred': 16403,
#   'rfr_pred': 19054,
#   'best_pred': 16843.0,
#   'real': 28130,
#   'mape': 40.12442232492001},
#  {'xgb_pred': 18921,
#   'dnn_pred': 16659,
#   'rfr_pred': 20003,
#   'best_pred': 18921.0,
#   'real': 13626,
#   'mape': 38.859533245266405},
#  {'xgb_pred': 13234,
#   'dnn_pred': 13432,
#   'rfr_pred': 14283,
#   'best_pred': 13432.0,
#   'real': 21956,
#   'mape': 38.82310074694844},
#  {'xgb_pred': 43671,
#   'dnn_pred': 43510,
#   'rfr_pred': 43404,
#   'best_pred': 43510.0,
#   'real': 31380,
#   'mape': 38.65519439133206},
#  {'xgb_pred': 11901,
#   'dnn_pred': 11351,
#   'rfr_pred': 12462,
#   'best_pred': 11901.0,
#   'real': 18351,
#   'mape': 35.14794834068988},
#  {'xgb_pred': 19117,
#   'dnn_pred': 18481,
#   'rfr_pred': 20271,
#   'best_pred': 19117.0,
#   'real': 14229,
#   'mape': 34.35237894440931},
#  {'xgb_pred': 15011,
#   'dnn_pred': 14641,
#   'rfr_pred': 16340,
#   'best_pred': 15011.0,
#   'real': 22416,
#   'mape': 33.034439685938615},
#  {'xgb_pred': 16050,
#   'dnn_pred': 17410,
#   'rfr_pred': 17858,
#   'best_pred': 17410.0,
#   'real': 13110,
#   'mape': 32.79938977879481},
#  {'xgb_pred': 54003,
#   'dnn_pred': 60768,
#   'rfr_pred': 54646,
#   'best_pred': 54646.0,
#   'real': 74495,
#   'mape': 26.644741257802533},
#  {'xgb_pred': 63961,
#   'dnn_pred': 69772,
#   'rfr_pred': 65652,
#   'best_pred': 65652.0,
#   'real': 87046,
#   'mape': 24.57780943409232},
#  {'xgb_pred': 818302,
#   'dnn_pred': 729585,
#   'rfr_pred': 911164,
#   'best_pred': 818302.0,
#   'real': 663222,
#   'mape': 23.382819025906862},
#  {'xgb_pred': 917715,
#   'dnn_pred': 823047,
#   'rfr_pred': 929467,
#   'best_pred': 917715.0,
#   'real': 747211,
#   'mape': 22.81872188712425},
#  {'xgb_pred': 11549,
#   'dnn_pred': 13590,
#   'rfr_pred': 14648,
#   'best_pred': 13590.0,
#   'real': 11087,
#   'mape': 22.57598989807883},
#  {'xgb_pred': 4588913,
#   'dnn_pred': 6295905,
#   'rfr_pred': 4913512,
#   'best_pred': 4913512.0,
#   'real': 6344489,
#   'mape': 22.55464545686816},
#  {'xgb_pred': 22572,
#   'dnn_pred': 24049,
#   'rfr_pred': 25173,
#   'best_pred': 24049.0,
#   'real': 19638,
#   'mape': 22.461554129748446},
#  {'xgb_pred': 34779,
#   'dnn_pred': 37117,
#   'rfr_pred': 34573,
#   'best_pred': 34779.0,
#   'real': 44795,
#   'mape': 22.3596383524947},
#  {'xgb_pred': 30669,
#   'dnn_pred': 19585,
#   'rfr_pred': 32741,
#   'best_pred': 30669.0,
#   'real': 25090,
#   'mape': 22.23595057791949},
#  {'xgb_pred': 789992,
#   'dnn_pred': 965779,
#   'rfr_pred': 726744,
#   'best_pred': 789992.0,
#   'real': 1004111,
#   'mape': 21.32423606553459},
#  {'xgb_pred': 1550584,
#   'dnn_pred': 1286848,
#   'rfr_pred': 1735706,
#   'best_pred': 1550584.0,
#   'real': 1286669,
#   'mape': 20.511491300404376},
#  {'xgb_pred': 11180,
#   'dnn_pred': 10806,
#   'rfr_pred': 12171,
#   'best_pred': 11180.0,
#   'real': 9352,
#   'mape': 19.546621043627034},
#  {'xgb_pred': 516328,
#   'dnn_pred': 411626,
#   'rfr_pred': 606159,
#   'best_pred': 516328.0,
#   'real': 432681,
#   'mape': 19.332256327409798},
#  {'xgb_pred': 29532,
#   'dnn_pred': 31961,
#   'rfr_pred': 32429,
#   'best_pred': 31961.0,
#   'real': 39551,
#   'mape': 19.190412378953756},
#  {'xgb_pred': 30905,
#   'dnn_pred': 30235,
#   'rfr_pred': 36280,
#   'best_pred': 30905.0,
#   'real': 38151,
#   'mape': 18.99294907079762},
#  {'xgb_pred': 200020,
#   'dnn_pred': 246768,
#   'rfr_pred': 198118,
#   'best_pred': 200020.0,
#   'real': 244678,
#   'mape': 18.251743107267508},
#  {'xgb_pred': 106622,
#   'dnn_pred': 137336,
#   'rfr_pred': 109653,
#   'best_pred': 109653.0,
#   'real': 133872,
#   'mape': 18.091161706704913},
#  {'xgb_pred': 21130,
#   'dnn_pred': 23433,
#   'rfr_pred': 28037,
#   'best_pred': 23433.0,
#   'real': 20022,
#   'mape': 17.03626011387474},
#  {'xgb_pred': 36943,
#   'dnn_pred': 34012,
#   'rfr_pred': 46737,
#   'best_pred': 36943.0,
#   'real': 31577,
#   'mape': 16.993381258510944},
#  {'xgb_pred': 20608,
#   'dnn_pred': 23574,
#   'rfr_pred': 22797,
#   'best_pred': 22797.0,
#   'real': 19563,
#   'mape': 16.531206870111944},
#  {'xgb_pred': 15224,
#   'dnn_pred': 15237,
#   'rfr_pred': 16053,
#   'best_pred': 15237.0,
#   'real': 13113,
#   'mape': 16.197666437886067},
#  {'xgb_pred': 10801,
#   'dnn_pred': 13862,
#   'rfr_pred': 11986,
#   'best_pred': 11986.0,
#   'real': 14269,
#   'mape': 15.999719672016258},
#  {'xgb_pred': 1965102,
#   'dnn_pred': 2312123,
#   'rfr_pred': 1888092,
#   'best_pred': 1965102.0,
#   'real': 2330004,
#   'mape': 15.661003157076125},
#  {'xgb_pred': 55740,
#   'dnn_pred': 67222,
#   'rfr_pred': 55986,
#   'best_pred': 55986.0,
#   'real': 66346,
#   'mape': 15.615108672715763},
#  {'xgb_pred': 6577,
#   'dnn_pred': 6614,
#   'rfr_pred': 7674,
#   'best_pred': 6614.0,
#   'real': 5729,
#   'mape': 15.447722115552454},
#  {'xgb_pred': 356617,
#   'dnn_pred': 404942,
#   'rfr_pred': 366050,
#   'best_pred': 366050.0,
#   'real': 432817,
#   'mape': 15.426150081905284},
#  {'xgb_pred': 49299,
#   'dnn_pred': 61638,
#   'rfr_pred': 58106,
#   'best_pred': 58106.0,
#   'real': 50508,
#   'mape': 15.043161479369605},
#  {'xgb_pred': 44129,
#   'dnn_pred': 42912,
#   'rfr_pred': 51765,
#   'best_pred': 44129.0,
#   'real': 51936,
#   'mape': 15.031962415280345},
#  {'xgb_pred': 46439,
#   'dnn_pred': 50315,
#   'rfr_pred': 51077,
#   'best_pred': 50315.0,
#   'real': 58975,
#   'mape': 14.684188215345486},
#  {'xgb_pred': 4043128,
#   'dnn_pred': 4863796,
#   'rfr_pred': 3866092,
#   'best_pred': 4043128.0,
#   'real': 4727456,
#   'mape': 14.47560802258128},
#  {'xgb_pred': 143597,
#   'dnn_pred': 157575,
#   'rfr_pred': 138573,
#   'best_pred': 143597.0,
#   'real': 167215,
#   'mape': 14.124330951170649},
#  {'xgb_pred': 52972,
#   'dnn_pred': 56167,
#   'rfr_pred': 62883,
#   'best_pred': 56167.0,
#   'real': 65382,
#   'mape': 14.094093175491725},
#  {'xgb_pred': 15625,
#   'dnn_pred': 15413,
#   'rfr_pred': 17150,
#   'best_pred': 15625.0,
#   'real': 13699,
#   'mape': 14.059420395649317},
#  {'xgb_pred': 33531,
#   'dnn_pred': 39480,
#   'rfr_pred': 34722,
#   'best_pred': 34722.0,
#   'real': 30475,
#   'mape': 13.936013125512714},
#  {'xgb_pred': 16147,
#   'dnn_pred': 16840,
#   'rfr_pred': 19036,
#   'best_pred': 16840.0,
#   'real': 14793,
#   'mape': 13.837625904143852},
#  {'xgb_pred': 33126,
#   'dnn_pred': 34425,
#   'rfr_pred': 37180,
#   'best_pred': 34425.0,
#   'real': 30261,
#   'mape': 13.760285516010706},
#  {'xgb_pred': 360243,
#   'dnn_pred': 415104,
#   'rfr_pred': 410228,
#   'best_pred': 410228.0,
#   'real': 360627,
#   'mape': 13.754100497189617},
#  {'xgb_pred': 34261,
#   'dnn_pred': 32671,
#   'rfr_pred': 37448,
#   'best_pred': 34261.0,
#   'real': 39679,
#   'mape': 13.65457798835656},
#  {'xgb_pred': 4130592,
#   'dnn_pred': 4930850,
#   'rfr_pred': 3818348,
#   'best_pred': 4130592.0,
#   'real': 4777338,
#   'mape': 13.537790292418078},
#  {'xgb_pred': 10582,
#   'dnn_pred': 15207,
#   'rfr_pred': 11187,
#   'best_pred': 11187.0,
#   'real': 9862,
#   'mape': 13.435408639221253},
#  {'xgb_pred': 24901,
#   'dnn_pred': 24988,
#   'rfr_pred': 26628,
#   'best_pred': 24988.0,
#   'real': 28835,
#   'mape': 13.341425351135772},
#  {'xgb_pred': 117488,
#   'dnn_pred': 146701,
#   'rfr_pred': 115778,
#   'best_pred': 117488.0,
#   'real': 135060,
#   'mape': 13.010513845698208},
#  {'xgb_pred': 58544,
#   'dnn_pred': 57703,
#   'rfr_pred': 69117,
#   'best_pred': 58544.0,
#   'real': 67247,
#   'mape': 12.941841271729594},
#  {'xgb_pred': 14896,
#   'dnn_pred': 18432,
#   'rfr_pred': 15878,
#   'best_pred': 15878.0,
#   'real': 14078,
#   'mape': 12.785907089075152},
#  {'xgb_pred': 9752,
#   'dnn_pred': 9089,
#   'rfr_pred': 10136,
#   'best_pred': 9752.0,
#   'real': 8647,
#   'mape': 12.778998496588411},
#  {'xgb_pred': 110676,
#   'dnn_pred': 122004,
#   'rfr_pred': 108862,
#   'best_pred': 110676.0,
#   'real': 126101,
#   'mape': 12.232258269165193},
#  {'xgb_pred': 39034,
#   'dnn_pred': 73238,
#   'rfr_pred': 43627,
#   'best_pred': 43627.0,
#   'real': 49356,
#   'mape': 11.607504660021071},
#  {'xgb_pred': 15401,
#   'dnn_pred': 12688,
#   'rfr_pred': 16319,
#   'best_pred': 15401.0,
#   'real': 17374,
#   'mape': 11.356049269022678},
#  {'xgb_pred': 37593,
#   'dnn_pred': 43014,
#   'rfr_pred': 41350,
#   'best_pred': 41350.0,
#   'real': 46310,
#   'mape': 10.71042971280501},
#  {'xgb_pred': 94954,
#   'dnn_pred': 100903,
#   'rfr_pred': 106562,
#   'best_pred': 100903.0,
#   'real': 91244,
#   'mape': 10.585901538731314},
#  {'xgb_pred': 27262,
#   'dnn_pred': 35037,
#   'rfr_pred': 27946,
#   'best_pred': 27946.0,
#   'real': 25294,
#   'mape': 10.484699928836879},
#  {'xgb_pred': 282025,
#   'dnn_pred': 308850,
#   'rfr_pred': 330312,
#   'best_pred': 308850.0,
#   'real': 279834,
#   'mape': 10.369004481228156},
#  {'xgb_pred': 70539,
#   'dnn_pred': 83319,
#   'rfr_pred': 69640,
#   'best_pred': 70539.0,
#   'real': 78642,
#   'mape': 10.303654535744258},
#  {'xgb_pred': 35124,
#   'dnn_pred': 32041,
#   'rfr_pred': 39480,
#   'best_pred': 35124.0,
#   'real': 31902,
#   'mape': 10.099680270829415},
#  {'xgb_pred': 310086,
#   'dnn_pred': 287610,
#   'rfr_pred': 337491,
#   'best_pred': 310086.0,
#   'real': 281644,
#   'mape': 10.09856414480692},
#  {'xgb_pred': 848938,
#   'dnn_pred': 772400,
#   'rfr_pred': 856192,
#   'best_pred': 848938.0,
#   'real': 773234,
#   'mape': 9.790567926397442},
#  {'xgb_pred': 81408,
#   'dnn_pred': 91275,
#   'rfr_pred': 80801,
#   'best_pred': 81408.0,
#   'real': 89910,
#   'mape': 9.456122789456122},
#  {'xgb_pred': 18777,
#   'dnn_pred': 24024,
#   'rfr_pred': 20255,
#   'best_pred': 20255.0,
#   'real': 18527,
#   'mape': 9.32692826685378},
#  {'xgb_pred': 94270,
#   'dnn_pred': 117119,
#   'rfr_pred': 93496,
#   'best_pred': 94270.0,
#   'real': 103961,
#   'mape': 9.321764892603959},
#  {'xgb_pred': 20013,
#   'dnn_pred': 39519,
#   'rfr_pred': 22794,
#   'best_pred': 22794.0,
#   'real': 20867,
#   'mape': 9.234676762352038},
#  {'xgb_pred': 412112,
#   'dnn_pred': 418179,
#   'rfr_pred': 391452,
#   'best_pred': 412112.0,
#   'real': 453645,
#   'mape': 9.155396841142304},
#  {'xgb_pred': 93524,
#   'dnn_pred': 83669,
#   'rfr_pred': 89319,
#   'best_pred': 89319.0,
#   'real': 98308,
#   'mape': 9.143711600276681},
#  {'xgb_pred': 10589,
#   'dnn_pred': 11952,
#   'rfr_pred': 12237,
#   'best_pred': 11952.0,
#   'real': 10965,
#   'mape': 9.001367989056087},
#  {'xgb_pred': 1596636,
#   'dnn_pred': 1770252,
#   'rfr_pred': 1548340,
#   'best_pred': 1596636.0,
#   'real': 1754542,
#   'mape': 8.999841554092178},
#  {'xgb_pred': 157937,
#   'dnn_pred': 149016,
#   'rfr_pred': 156627,
#   'best_pred': 156627.0,
#   'real': 143737,
#   'mape': 8.967767519845273},
#  {'xgb_pred': 52865,
#   'dnn_pred': 60409,
#   'rfr_pred': 58202,
#   'best_pred': 58202.0,
#   'real': 53416,
#   'mape': 8.959862213568968},
#  {'xgb_pred': 401841,
#   'dnn_pred': 402209,
#   'rfr_pred': 432210,
#   'best_pred': 402209.0,
#   'real': 369161,
#   'mape': 8.952191591202755},
#  {'xgb_pred': 173347,
#   'dnn_pred': 184868,
#   'rfr_pred': 179715,
#   'best_pred': 179715.0,
#   'real': 165377,
#   'mape': 8.669887590172756},
#  {'xgb_pred': 1184040,
#   'dnn_pred': 1179642,
#   'rfr_pred': 1259664,
#   'best_pred': 1184040.0,
#   'real': 1089733,
#   'mape': 8.654138215507835},
#  {'xgb_pred': 89729,
#   'dnn_pred': 106599,
#   'rfr_pred': 102471,
#   'best_pred': 102471.0,
#   'real': 94388,
#   'mape': 8.56358859177014},
#  {'xgb_pred': 28840,
#   'dnn_pred': 32710,
#   'rfr_pred': 29912,
#   'best_pred': 29912.0,
#   'real': 32690,
#   'mape': 8.498011624349953},
#  {'xgb_pred': 50669,
#   'dnn_pred': 51489,
#   'rfr_pred': 50252,
#   'best_pred': 50669.0,
#   'real': 46710,
#   'mape': 8.475701134660673},
#  {'xgb_pred': 1431633,
#   'dnn_pred': 1402674,
#   'rfr_pred': 1489143,
#   'best_pred': 1431633.0,
#   'real': 1558644,
#   'mape': 8.148813969065419},
#  {'xgb_pred': 28083,
#   'dnn_pred': 28371,
#   'rfr_pred': 29695,
#   'best_pred': 28371.0,
#   'real': 30792,
#   'mape': 7.862431800467654},
#  {'xgb_pred': 253817,
#   'dnn_pred': 294750,
#   'rfr_pred': 254765,
#   'best_pred': 254765.0,
#   'real': 276319,
#   'mape': 7.800404604822687},
#  {'xgb_pred': 26971,
#   'dnn_pred': 23498,
#   'rfr_pred': 28610,
#   'best_pred': 26971.0,
#   'real': 29229,
#   'mape': 7.725204420267542},
#  {'xgb_pred': 37088,
#   'dnn_pred': 40246,
#   'rfr_pred': 41180,
#   'best_pred': 40246.0,
#   'real': 43430,
#   'mape': 7.331337784941285},
#  {'xgb_pred': 19693,
#   'dnn_pred': 22811,
#   'rfr_pred': 19997,
#   'best_pred': 19997.0,
#   'real': 21553,
#   'mape': 7.219412610773442},
#  {'xgb_pred': 185304,
#   'dnn_pred': 194045,
#   'rfr_pred': 202130,
#   'best_pred': 194045.0,
#   'real': 181070,
#   'mape': 7.165737007787043},
#  {'xgb_pred': 50749,
#   'dnn_pred': 56487,
#   'rfr_pred': 60567,
#   'best_pred': 56487.0,
#   'real': 52737,
#   'mape': 7.110757153421695},
#  {'xgb_pred': 78884,
#   'dnn_pred': 83040,
#   'rfr_pred': 90292,
#   'best_pred': 83040.0,
#   'real': 77551,
#   'mape': 7.077922915242872},
#  {'xgb_pred': 578850,
#   'dnn_pred': 611891,
#   'rfr_pred': 579446,
#   'best_pred': 579446.0,
#   'real': 622865,
#   'mape': 6.970852431907396},
#  {'xgb_pred': 2398887,
#   'dnn_pred': 2154208,
#   'rfr_pred': 2421486,
#   'best_pred': 2398887.0,
#   'real': 2243000,
#   'mape': 6.949933125278644},
#  {'xgb_pred': 259729,
#   'dnn_pred': 278164,
#   'rfr_pred': 298274,
#   'best_pred': 278164.0,
#   'real': 260394,
#   'mape': 6.824273984807637},
#  {'xgb_pred': 133208,
#   'dnn_pred': 149233,
#   'rfr_pred': 148962,
#   'best_pred': 148962.0,
#   'real': 139591,
#   'mape': 6.713183514696507},
#  {'xgb_pred': 41819,
#   'dnn_pred': 41830,
#   'rfr_pred': 40057,
#   'best_pred': 41819.0,
#   'real': 44802,
#   'mape': 6.658184902459712},
#  {'xgb_pred': 23969,
#   'dnn_pred': 25984,
#   'rfr_pred': 24194,
#   'best_pred': 24194.0,
#   'real': 25881,
#   'mape': 6.5182952745257134},
#  {'xgb_pred': 154519,
#   'dnn_pred': 173339,
#   'rfr_pred': 160947,
#   'best_pred': 160947.0,
#   'real': 151100,
#   'mape': 6.516876240900066},
#  {'xgb_pred': 116565,
#   'dnn_pred': 111082,
#   'rfr_pred': 116109,
#   'best_pred': 116109.0,
#   'real': 109182,
#   'mape': 6.344452382260812},
#  {'xgb_pred': 23415,
#   'dnn_pred': 19588,
#   'rfr_pred': 27855,
#   'best_pred': 23415.0,
#   'real': 22029,
#   'mape': 6.291706387035272},
#  {'xgb_pred': 27397,
#   'dnn_pred': 26860,
#   'rfr_pred': 30480,
#   'best_pred': 27397.0,
#   'real': 25816,
#   'mape': 6.124109079640533},
#  {'xgb_pred': 15465,
#   'dnn_pred': 15624,
#   'rfr_pred': 16678,
#   'best_pred': 15624.0,
#   'real': 16617,
#   'mape': 5.975807907564542},
#  {'xgb_pred': 861423,
#   'dnn_pred': 992302,
#   'rfr_pred': 884817,
#   'best_pred': 884817.0,
#   'real': 940945,
#   'mape': 5.965067033673594},
#  {'xgb_pred': 703015,
#   'dnn_pred': 747691,
#   'rfr_pred': 749048,
#   'best_pred': 747691.0,
#   'real': 705863,
#   'mape': 5.925795798901486},
#  {'xgb_pred': 97800,
#   'dnn_pred': 120592,
#   'rfr_pred': 97705,
#   'best_pred': 97800.0,
#   'real': 92391,
#   'mape': 5.854466344124427},
#  {'xgb_pred': 55542,
#   'dnn_pred': 64521,
#   'rfr_pred': 58638,
#   'best_pred': 58638.0,
#   'real': 55405,
#   'mape': 5.83521342839094},
#  {'xgb_pred': 40626,
#   'dnn_pred': 46403,
#   'rfr_pred': 41179,
#   'best_pred': 41179.0,
#   'real': 43682,
#   'mape': 5.7300489904308405},
#  {'xgb_pred': 92514,
#   'dnn_pred': 102197,
#   'rfr_pred': 98419,
#   'best_pred': 98419.0,
#   'real': 93092,
#   'mape': 5.722296223091136},
#  {'xgb_pred': 101171,
#   'dnn_pred': 102531,
#   'rfr_pred': 106134,
#   'best_pred': 102531.0,
#   'real': 96990,
#   'mape': 5.712960098979276},
#  {'xgb_pred': 10317,
#   'dnn_pred': 10205,
#   'rfr_pred': 11108,
#   'best_pred': 10317.0,
#   'real': 9760,
#   'mape': 5.706967213114754},
#  {'xgb_pred': 339961,
#   'dnn_pred': 360126,
#   'rfr_pred': 381269,
#   'best_pred': 360126.0,
#   'real': 341110,
#   'mape': 5.574741285802234},
#  {'xgb_pred': 1584629,
#   'dnn_pred': 1618314,
#   'rfr_pred': 1663138,
#   'best_pred': 1618314.0,
#   'real': 1533202,
#   'mape': 5.551258086018672},
#  {'xgb_pred': 75047,
#   'dnn_pred': 83863,
#   'rfr_pred': 82098,
#   'best_pred': 82098.0,
#   'real': 77798,
#   'mape': 5.527134373634284},
#  {'xgb_pred': 27912,
#   'dnn_pred': 34904,
#   'rfr_pred': 29632,
#   'best_pred': 29632.0,
#   'real': 31359,
#   'mape': 5.507190918077745},
#  {'xgb_pred': 70726,
#   'dnn_pred': 92031,
#   'rfr_pred': 73942,
#   'best_pred': 73942.0,
#   'real': 70154,
#   'mape': 5.399549562391311},
#  {'xgb_pred': 79044,
#   'dnn_pred': 82883,
#   'rfr_pred': 92549,
#   'best_pred': 82883.0,
#   'real': 78718,
#   'mape': 5.291038898345994},
#  {'xgb_pred': 102281,
#   'dnn_pred': 100331,
#   'rfr_pred': 106413,
#   'best_pred': 102281.0,
#   'real': 97298,
#   'mape': 5.121379678924541},
#  {'xgb_pred': 17260,
#   'dnn_pred': 21524,
#   'rfr_pred': 18818,
#   'best_pred': 18818.0,
#   'real': 19803,
#   'mape': 4.9739938393172745},
#  {'xgb_pred': 282610,
#   'dnn_pred': 262809,
#   'rfr_pred': 304018,
#   'best_pred': 282610.0,
#   'real': 270598,
#   'mape': 4.439057199240201},
#  {'xgb_pred': 124644,
#   'dnn_pred': 124940,
#   'rfr_pred': 125897,
#   'best_pred': 124940.0,
#   'real': 119665,
#   'mape': 4.4081393891279825},
#  {'xgb_pred': 116616,
#   'dnn_pred': 121652,
#   'rfr_pred': 126099,
#   'best_pred': 121652.0,
#   'real': 116566,
#   'mape': 4.363193384005628},
#  {'xgb_pred': 657666,
#   'dnn_pred': 657428,
#   'rfr_pred': 663972,
#   'best_pred': 657666.0,
#   'real': 630627,
#   'mape': 4.287637541684704},
#  {'xgb_pred': 70974,
#   'dnn_pred': 65484,
#   'rfr_pred': 86941,
#   'best_pred': 70974.0,
#   'real': 68167,
#   'mape': 4.117828274678363},
#  {'xgb_pred': 25059,
#   'dnn_pred': 26186,
#   'rfr_pred': 26576,
#   'best_pred': 26186.0,
#   'real': 27256,
#   'mape': 3.925741121221016},
#  {'xgb_pred': 38684,
#   'dnn_pred': 46705,
#   'rfr_pred': 44062,
#   'best_pred': 44062.0,
#   'real': 42413,
#   'mape': 3.8879588805319125},
#  {'xgb_pred': 202700,
#   'dnn_pred': 224543,
#   'rfr_pred': 214240,
#   'best_pred': 214240.0,
#   'real': 222732,
#   'mape': 3.812653772246467},
#  {'xgb_pred': 183747,
#   'dnn_pred': 197170,
#   'rfr_pred': 183003,
#   'best_pred': 183747.0,
#   'real': 190964,
#   'mape': 3.7792463500974005},
#  {'xgb_pred': 46192,
#   'dnn_pred': 39884,
#   'rfr_pred': 49662,
#   'best_pred': 46192.0,
#   'real': 47983,
#   'mape': 3.7325719525665337},
#  {'xgb_pred': 54103,
#   'dnn_pred': 40233,
#   'rfr_pred': 53211,
#   'best_pred': 53211.0,
#   'real': 51306,
#   'mape': 3.7130160215179506},
#  {'xgb_pred': 881560,
#   'dnn_pred': 978443,
#   'rfr_pred': 884176,
#   'best_pred': 884176.0,
#   'real': 917973,
#   'mape': 3.6816986991992136},
#  {'xgb_pred': 186744,
#   'dnn_pred': 234296,
#   'rfr_pred': 202726,
#   'best_pred': 202726.0,
#   'real': 210460,
#   'mape': 3.674807564382781},
#  {'xgb_pred': 1323777,
#   'dnn_pred': 1350147,
#   'rfr_pred': 1384421,
#   'best_pred': 1350147.0,
#   'real': 1304262,
#   'mape': 3.518081489762026},
#  {'xgb_pred': 31817,
#   'dnn_pred': 45523,
#   'rfr_pred': 35792,
#   'best_pred': 35792.0,
#   'real': 37097,
#   'mape': 3.517804674232418},
#  {'xgb_pred': 18885,
#   'dnn_pred': 17904,
#   'rfr_pred': 21023,
#   'best_pred': 18885.0,
#   'real': 18245,
#   'mape': 3.507810359002467},
#  {'xgb_pred': 57102,
#   'dnn_pred': 66595,
#   'rfr_pred': 61940,
#   'best_pred': 61940.0,
#   'real': 64162,
#   'mape': 3.4631090053302582},
#  {'xgb_pred': 42705,
#   'dnn_pred': 54359,
#   'rfr_pred': 48232,
#   'best_pred': 48232.0,
#   'real': 49944,
#   'mape': 3.427839179881467},
#  {'xgb_pred': 288184,
#   'dnn_pred': 321206,
#   'rfr_pred': 291400,
#   'best_pred': 291400.0,
#   'real': 301658,
#   'mape': 3.4005396840130215},
#  {'xgb_pred': 715191,
#   'dnn_pred': 782850,
#   'rfr_pred': 734718,
#   'best_pred': 734718.0,
#   'real': 759959,
#   'mape': 3.321363389340741},
#  {'xgb_pred': 30805,
#   'dnn_pred': 32587,
#   'rfr_pred': 32675,
#   'best_pred': 32587.0,
#   'real': 31557,
#   'mape': 3.263935101562252},
#  {'xgb_pred': 757329,
#   'dnn_pred': 782542,
#   'rfr_pred': 803880,
#   'best_pred': 782542.0,
#   'real': 758334,
#   'mape': 3.192260929880501},
#  {'xgb_pred': 53403,
#   'dnn_pred': 57343,
#   'rfr_pred': 56157,
#   'best_pred': 56157.0,
#   'real': 54445,
#   'mape': 3.144457709615208},
#  {'xgb_pred': 122680,
#   'dnn_pred': 140416,
#   'rfr_pred': 131969,
#   'best_pred': 131969.0,
#   'real': 128294,
#   'mape': 2.8645143186742947},
#  {'xgb_pred': 117055,
#   'dnn_pred': 130920,
#   'rfr_pred': 117703,
#   'best_pred': 117703.0,
#   'real': 121029,
#   'mape': 2.7481016946351704},
#  {'xgb_pred': 41866,
#   'dnn_pred': 48472,
#   'rfr_pred': 51891,
#   'best_pred': 48472.0,
#   'real': 49823,
#   'mape': 2.711599060674789},
#  {'xgb_pred': 10078,
#   'dnn_pred': 11394,
#   'rfr_pred': 11668,
#   'best_pred': 11394.0,
#   'real': 11100,
#   'mape': 2.6486486486486487},
#  {'xgb_pred': 1192355,
#   'dnn_pred': 1329727,
#   'rfr_pred': 1171026,
#   'best_pred': 1192355.0,
#   'real': 1224120,
#   'mape': 2.59492533411757},
#  {'xgb_pred': 11303,
#   'dnn_pred': 13006,
#   'rfr_pred': 11553,
#   'best_pred': 11553.0,
#   'real': 11269,
#   'mape': 2.5201881267193182},
#  {'xgb_pred': 198475,
#   'dnn_pred': 192194,
#   'rfr_pred': 195152,
#   'best_pred': 195152.0,
#   'real': 190442,
#   'mape': 2.473193938311927},
#  {'xgb_pred': 1141187,
#   'dnn_pred': 1183337,
#   'rfr_pred': 1191083,
#   'best_pred': 1183337.0,
#   'real': 1154837,
#   'mape': 2.4678807485385383},
#  {'xgb_pred': 605288,
#   'dnn_pred': 642755,
#   'rfr_pred': 696678,
#   'best_pred': 642755.0,
#   'real': 627928,
#   'mape': 2.3612579786217527},
#  {'xgb_pred': 35895,
#   'dnn_pred': 37105,
#   'rfr_pred': 37920,
#   'best_pred': 37105.0,
#   'real': 36328,
#   'mape': 2.138846069147765},
#  {'xgb_pred': 125644,
#   'dnn_pred': 129981,
#   'rfr_pred': 123889,
#   'best_pred': 125644.0,
#   'real': 128247,
#   'mape': 2.0296771074567044},
#  {'xgb_pred': 67471,
#   'dnn_pred': 70262,
#   'rfr_pred': 72938,
#   'best_pred': 70262.0,
#   'real': 68873,
#   'mape': 2.0167554774730303},
#  {'xgb_pred': 37315,
#   'dnn_pred': 43142,
#   'rfr_pred': 37113,
#   'best_pred': 37315.0,
#   'real': 38015,
#   'mape': 1.8413784032618703},
#  {'xgb_pred': 1324266,
#   'dnn_pred': 1405841,
#   'rfr_pred': 1319095,
#   'best_pred': 1324266.0,
#   'real': 1347968,
#   'mape': 1.7583503465957648},
#  {'xgb_pred': 161627,
#   'dnn_pred': 206863,
#   'rfr_pred': 175033,
#   'best_pred': 175033.0,
#   'real': 172021,
#   'mape': 1.750949012039228},
#  {'xgb_pred': 42795,
#   'dnn_pred': 42477,
#   'rfr_pred': 39601,
#   'best_pred': 42477.0,
#   'real': 41750,
#   'mape': 1.7413173652694611},
#  {'xgb_pred': 207843,
#   'dnn_pred': 222533,
#   'rfr_pred': 212876,
#   'best_pred': 212876.0,
#   'real': 216479,
#   'mape': 1.664364672785813},
#  {'xgb_pred': 287549,
#   'dnn_pred': 229908,
#   'rfr_pred': 338306,
#   'best_pred': 287549.0,
#   'real': 292271,
#   'mape': 1.6156238559419172},
#  {'xgb_pred': 58146,
#   'dnn_pred': 61339,
#   'rfr_pred': 61507,
#   'best_pred': 61339.0,
#   'real': 60379,
#   'mape': 1.5899567730502329},
#  {'xgb_pred': 127402,
#   'dnn_pred': 153130,
#   'rfr_pred': 134570,
#   'best_pred': 134570.0,
#   'real': 136734,
#   'mape': 1.5826348969532082},
#  {'xgb_pred': 447009,
#   'dnn_pred': 458627,
#   'rfr_pred': 467006,
#   'best_pred': 458627.0,
#   'real': 451656,
#   'mape': 1.5434312839860425},
#  {'xgb_pred': 189260,
#   'dnn_pred': 226324,
#   'rfr_pred': 208181,
#   'best_pred': 208181.0,
#   'real': 211421,
#   'mape': 1.532487312045634},
#  {'xgb_pred': 557907,
#   'dnn_pred': 607102,
#   'rfr_pred': 612304,
#   'best_pred': 607102.0,
#   'real': 598523,
#   'mape': 1.4333617922786595},
#  {'xgb_pred': 348782,
#   'dnn_pred': 346134,
#   'rfr_pred': 388385,
#   'best_pred': 348782.0,
#   'real': 343975,
#   'mape': 1.3974852823606367},
#  {'xgb_pred': 2771960,
#   'dnn_pred': 2958412,
#   'rfr_pred': 2687175,
#   'best_pred': 2771960.0,
#   'real': 2803943,
#   'mape': 1.1406437292056222},
#  {'xgb_pred': 128956,
#   'dnn_pred': 134561,
#   'rfr_pred': 132328,
#   'best_pred': 132328.0,
#   'real': 130844,
#   'mape': 1.1341750481489408},
#  {'xgb_pred': 194237,
#   'dnn_pred': 219515,
#   'rfr_pred': 193779,
#   'best_pred': 194237.0,
#   'real': 196380,
#   'mape': 1.0912516549546798},
#  {'xgb_pred': 773476,
#   'dnn_pred': 864828,
#   'rfr_pred': 822061,
#   'best_pred': 822061.0,
#   'real': 813244,
#   'mape': 1.0841764587257945},
#  {'xgb_pred': 138503,
#   'dnn_pred': 152370,
#   'rfr_pred': 145505,
#   'best_pred': 145505.0,
#   'real': 144060,
#   'mape': 1.003054282937665},
#  {'xgb_pred': 291770,
#   'dnn_pred': 327579,
#   'rfr_pred': 308818,
#   'best_pred': 308818.0,
#   'real': 305757,
#   'mape': 1.0011218058785245},
#  {'xgb_pred': 65962,
#   'dnn_pred': 66486,
#   'rfr_pred': 75578,
#   'best_pred': 66486.0,
#   'real': 65894,
#   'mape': 0.8984126020578505},
#  {'xgb_pred': 2442456,
#   'dnn_pred': 2543180,
#   'rfr_pred': 2624776,
#   'best_pred': 2543180.0,
#   'real': 2523708,
#   'mape': 0.7715631126897406},
#  {'xgb_pred': 34783,
#   'dnn_pred': 36977,
#   'rfr_pred': 36023,
#   'best_pred': 36023.0,
#   'real': 36276,
#   'mape': 0.6974308082478774},
#  {'xgb_pred': 881756,
#   'dnn_pred': 866511,
#   'rfr_pred': 922800,
#   'best_pred': 881756.0,
#   'real': 877427,
#   'mape': 0.49337437758354824},
#  {'xgb_pred': 291152,
#   'dnn_pred': 294089,
#   'rfr_pred': 300395,
#   'best_pred': 294089.0,
#   'real': 295223,
#   'mape': 0.38411641369405497},
#  {'xgb_pred': 648718,
#   'dnn_pred': 700299,
#   'rfr_pred': 669712,
#   'best_pred': 669712.0,
#   'real': 672265,
#   'mape': 0.37976095736056464},
#  {'xgb_pred': 31071,
#   'dnn_pred': 32155,
#   'rfr_pred': 32692,
#   'best_pred': 32155.0,
#   'real': 32273,
#   'mape': 0.3656307129798903},
#  {'xgb_pred': 16875,
#   'dnn_pred': 18893,
#   'rfr_pred': 16650,
#   'best_pred': 16875.0,
#   'real': 16821,
#   'mape': 0.32102728731942215},
#  {'xgb_pred': 61958,
#   'dnn_pred': 63393,
#   'rfr_pred': 72730,
#   'best_pred': 63393.0,
#   'real': 63564,
#   'mape': 0.26902020011327166},
#  {'xgb_pred': 462973,
#   'dnn_pred': 480642,
#   'rfr_pred': 440848,
#   'best_pred': 462973.0,
#   'real': 464198,
#   'mape': 0.2638960098923304},
#  {'xgb_pred': 117815,
#   'dnn_pred': 132007,
#   'rfr_pred': 120714,
#   'best_pred': 120714.0,
#   'real': 120592,
#   'mape': 0.10116757330502853},
#  {'xgb_pred': 632633,
#   'dnn_pred': 686820,
#   'rfr_pred': 633726,
#   'best_pred': 633726.0,
#   'real': 633867,
#   'mape': 0.02224441404900397},
#  {'xgb_pred': 528306,
#   'dnn_pred': 561035,
#   'rfr_pred': 559974,
#   'best_pred': 559974.0,
#   'real': 560004,
#   'mape': 0.005357104592110057}]

# %%
# 최적의 pred을 골라냈을 때 mape 평균
print(np.mean(mape_list))
# Out:
# 12.499723415003894
