# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 1727, 191
train = pd.read_csv('/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/d-optimal/d-optimal-of-spmm/train-test-csv/1727-nonsquare-train-from-1918-nonsquare-spmm-over-3s.csv')
test = pd.read_csv('/Users/bdlab/Desktop/sparse-matrix-multiplication/scenario-extraction/d-optimal/d-optimal-of-spmm/train-test-csv/191-nonsquare-test-from-1918-nonsquare-spmm-over-3s.csv')

# %%
train
# Out:
#           lr     lc     rc      ld      rd      lnnz      rnnz       lr*lc  \
# 0      97366  33288   5958 0.00056 0.13000   1823595  25785518  3241119408
# 1      37277   6335   8305 0.00015 0.20000     36129  10524778   236149795
# 2     122335  65522   2027 0.00041 0.25000   3294205  33216643  8015633870
# 3      85283  55401   5954 0.00002 0.13000     78006  42884765  4724763483
# 4      88648  49392  11945 0.00296 0.00500  12968430   2949991  4378502016
# ...      ...    ...    ...     ...     ...       ...       ...         ...
# 1721   20222  30795  11372 0.00013 0.15000     83218  52534062   622736490
# 1722   15333  43901   7034 0.00013 0.20000     89951  61765624   673134033
# 1723   26350  35302  46027 0.00032 0.00500    297128   8124377   930207700
# 1724    5352   1297  47635 0.00861 0.03000     59755   1853860     6941544
# 1725  126147  18767    270 0.00952 0.13000  22540844    660023  2367400749
#
# ...

# %%
target = train['bz_smsm'].to_numpy()
feature_1 = train['lr'].to_numpy()
feature_2 = train['lc'].to_numpy()
feature_3 = train['rc'].to_numpy()
feature_4 = train['ld'].to_numpy()
feature_5 = train['rd'].to_numpy()
feature_6 = train['lnnz'].to_numpy()
feature_7 = train['rnnz'].to_numpy()
feature_8 = train['lr*lc'].to_numpy()
feature_9 = train['lc*rc'].to_numpy()
feature_10 = train['lr*rc'].to_numpy()
feature_11 = train['lr*lc*rc'].to_numpy()
feature_12 = train['ld*rd'].to_numpy()
feature_13 = train['lr*rc*ld*rd'].to_numpy()
feature_14 = train['lr*lc*rc*ld*rd'].to_numpy()
feature_15 = train['lnnz*rnnz'].to_numpy()

# %%
pd.options.display.float_format = '{:.5f}'.format
np.set_printoptions(precision=6, suppress=True)

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_1,target, marker='^')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_2,target, marker='^')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_3,target, marker='^')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_4,target, marker='^')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_5,target, marker='^')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_6,target, marker='^')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_7,target, marker='^')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_8,target, marker='^')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_9,target, marker='^')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_10,target, marker='^')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_11,target, marker='^')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_12,target, marker='^')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_13,target, marker='^')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_14,target, marker='^')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(feature_15,target, marker='^')
plt.show()
